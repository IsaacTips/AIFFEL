# %% [markdown]
# # 6. 딥러닝과 신경망의 본질

# %% [markdown]
# ## 1. 들어가며

# %% [markdown]
# ### 학습 목표
# ---
# * 딥러닝과 머신러닝의 차이를 설명할 수 있다.
# * 딥러닝은 특히 데이터를 '표현'하는 것을 목표로 하며, '표현 학습'이라고 이야기 할 수 있는 본질을 이해한다.
# * 연결주의를 계승하여 채택한 신경망 모델의 본질을 함수 차원에서 이해한다.
# * 선형성이 무엇인지 설명할 수 있다.

# %% [markdown]
# ### 학습 내용
# ---
#
# * Deep Learning == Representation Learning ?
# * 조금 더 파고들어보자, 딥러닝을 관통하는 철학 속으로
# * 이번에는 '신경망', 그 본질에 대하여
# * 현시대 AI: 어디까지 왔나, 그리고 어디를 향해 가는가
#
# 어쩌면 오늘 나누는 이야기들은 오늘이 지나고 나면 다시 깊게 고민할 필요가 없는 이야기일 수도 있다. 하지만 한 번쯤 생각해 보면 좋을, 새로운 관점을 제시할 수 있는 중요한 이야기가 될 수도 있다. 깊게 음미해 보고, 신경망을 더욱 풍부한 관점에서 바라볼 수 있는 계기가 되었으면 좋겠다.
#
# 오늘 하려는 이야기는 딥러닝과 신경망에 대한 이야기이다.
#
# 딥러닝이라는 기술과 그 본질에 관심이 있는 사람이라면 분명 흥미로워 할 내용이 될 것임을 장담한다!

# %% [markdown]
# ## 2. Deep Learning == Representation Learning ? (1) Deep Learning
#
# 이런 질문은 많이 받아봤을 것이다.
#
# > _"딥러닝과 머신러닝, 이들은 무엇을 하는 친구들이고 그 차이는 무엇인가?"_
#
# 사실 위의 질문은 관점에 따라, 혹은 중요하게 생각하는 포인트에 따라 답이 다양하게 달라질 수 있다.
#
# 그 중, 일반적으로 많이 설명되는 방식은 다음과 같은 이미지를 통해서 이루어진다.
#
# <img src="./image/q.jpg" />
#
# [https://blogs.nvidia.com/blog/2016/07/29/whats-difference-artificial-intelligence-machine-learning-deep-learning-ai/](https://blogs.nvidia.com/blog/2016/07/29/whats-difference-artificial-intelligence-machine-learning-deep-learning-ai/)
#
# 인공지능이 가장 큰 범주이고, 그 안에는 머신러닝이, 또 그 안에 딥러닝이 있다는 설명이다.
#
# 위의 이미지로 설명한 내용은 다음 글로 한번 읽어보자.
#
# * **[인공 지능, 머신 러닝, 딥 러닝 차이점이 무엇일까요?](https://wendys.tistory.com/136)**
#
# __위 글에서 설명하는 인공지능, 머신러닝, 딥러닝을 다시 한 번 정의해보자.__
#
# - 인공지능은 사람이 직접 프로그래밍 한 내용이 아니라 기계가 자체 규칙 시스템을 구축하는 과학을 말한다.
# - 그 중에서도 머신러닝은 데이터를 통해 스스로 학습하는 방법론을 말한다. 데이터를 분석하고, 데이터 안에 있는 패턴을 학습하며, 학습한 내용을 토대로 판단이나 예측을 한다.
# - 머신러닝의 하위 집합인 딥러닝은 학습하는 모델의 형태가 신경망인 방법론을 말한다.

# %% [markdown]
# 하지만 여전히 많은 의문이 남는다.
#
# 딥러닝을 단순히 머신러닝의 하위 집합 중 하나라고만 설명하기엔 그 특성을 뚜렷하게 뒷받침하지 못하는 것 같다.
#
# 뇌를 구성하는 신경세포를 닮은 뉴런의 형태를 가지는 '신경망'을 모델로 활용하는 것이 딥러닝이라는데, 그렇다면 왜 하필 신경망일까?<br>
# 그리고 그 신경망이 뭐길래 그토록 잘 되고, 이전에는 풀지 못했던 많은 문제들을 해결하고 있는 걸까?
#
# 딥러닝은 이미지를 분류하는 대회인 ILSVRC에서 2012년 CNN을 활용한 신경망 모델이 우승한 이후 갑자기 엄청난 유명세와 인기를 얻었다.<br>
# 하지만 이 전에도 신경망 구조가 아닌 머신러닝 알고리즘은 언제나 존재해 왔고, 실제로 아직까지도 딥러닝보다 머신러닝이 더 많이 활용되는 문제들도 많다.
#
# 그러니까, '왜 딥러닝이냐'는 본질적인 의문을 갖게 된다. 신경망을 모델로 하는 딥러닝은 어디서부터 왔고, 그 이면에 담긴 철학은 무엇일까?
#
# <img src = "./image/neural.jpg" />
#
# [신경세포를 모사한 형태라고 일컬어지는 신경망의 '노드', 입력을 받아 출력한다는 점이 같다.]<br>
# [https://untitledtblog.tistory.com/141](https://untitledtblog.tistory.com/141)
#
# 딥러닝의 대가 중 한 명이라고 불리는 조슈아 벤지오는 본인의 SNS에 다음과 같은 글을 남겼다. 개인적으로 한 문장 한 문장 뜯어 읽어보는 것을 권다.
#
# <img src="./image/ben.jpg" />
#
# [https://www.facebook.com/yoshua.bengio/posts/2269432439828350](https://www.facebook.com/yoshua.bengio/posts/2269432439828350)
#
# 흥미롭게 느껴진다면 [링크](https://www.facebook.com/yoshua.bengio/posts/2269432439828350)에 직접 방문해서 댓글도 읽어보는 것을 추천한다. 딥러닝의 정의, 함의, 또는 그 철학에 대한 논쟁이 뜨겁다.
#
# __댓글 중 Hunar Ahmad라는 사람은 "이러한 정의는 비판을 피하기 위한 아주 일반적인 정의로밖에 보이지 않는다. 나는 딥러닝을 그저 'several layers of feed forward matrix multiplications with a loss function that is optimized by back-propagation (손실함수와 역전파로 최적화시키는 순방향 행렬 연산)' 일 뿐이라고 생각한다." 라고 반박하였다. 이에 대해 벤지오는 뭐라고 답했을까?__
#
# * 해당 정의는 딥러닝의 하위 방법론 중 하나인 RNN과 attention-based 를 배제한다고 답했다. 오늘 RNN과 attention-based 방법을 자세히 설명하지는 않겠지만, 두 가지 모두 단순한 '순방향 행렬 연산'만으로 이루어지지는 않으며, 그 성능을 인정받아 활발하게 응용되고 있는 방법론들이다.

# %% [markdown]
# 조슈아 벤지오는 딥러닝을 다음과 같이 정의한다.
#
# > ***Deep learning is inspired by neural networks of the brain to build learning machines which discover rich and useful internal representations, computed as a composition of learned features and functions.***
#
# 의역하자면 다음과 같다.
#
# ***뇌의 신경 구조로부터 영감을 받아 신경망 형태로 설계된 딥러닝의 목표는, "합성된 함수를 학습시켜서 풍부하면서도 유용한 '내재적 표현'을 찾아내는 machine을 구축하는 것"이다.***
#
# 여기서 **`internal representation`**, 즉 '내재적 표현'이라는 단어를 사용한다. **표현(Representation)** 은 딥러닝에서 굉장히 중요하게 여겨지는 개념이다. 벤지오가 언급했듯 데이터의 '좋은 표현'을 찾아낼 수 있는 machine을 만드는 것이 딥러닝의 궁극적인 목표이다.

# %% [markdown]
# ## 3. Deep Learning == Representation Learning ? (2) Representation Learning
#
# 그렇다면 '내재적 표현', 혹은 '표현(Representation)'은 무엇을 의미할까?
#
# 다음과 같은 물체가 있다고 해보자.
#
# <img src="./image/flower.jpg" />
#
# [https://www.pngflow.com/ko/free-transparent-png-hnagg](https://www.pngflow.com/ko/free-transparent-png-hnagg)
#
# 우리 눈에 꽃의 이미지가 보인다. 보다 엄밀하게 이야기하기 위해 위에 보이는 것을 '꽃'이라는 표현 대신 '데이터'라고 지칭하겠다.
#
# 위의 데이터는 다양한 방법으로 **'표현'** 될 수 있다. 몇 가지 다른 방법으로 위 데이터를 표현해보겠다.
#
# <img src="./image/flower2.jpg" />
#
# 총 네 가지 방법으로 왼쪽의 데이터를 표현해 보겠다.
#
# 1. 데이터는 **분자 형태**로 표현될 수 있다. 아니, 사실 분자 형태는 실제 데이터(물체) 그 자체라고도 할 수 있다. 아무런 가공을 거치지 않은, 데이터가 존재하는 형태 그대로의 표현이다.
# 2. 혹은 **이미지**로 표현해볼 수도 있다. 분자 형태, 혹은 데이터 그 자체보다는 아주 조금 가공된 형태이다. '시각적' 표현이라고도 할 수 있겠다. 보통 이미지를 컴퓨터에서 표현할 때에는 (14x14)와 같이 특정 사이즈를 가지는 2차원 배열로 표현된다. 컬러 이미지라면 R, G, B의 3채널을 가지기 때문에 3차원 배열로 표현하기도 한다. 디지털 세상에서 RGB 색상은 이 [링크](https://www.w3schools.com/colors/colors_rgb.asp)처럼 Red, Green, Blue 세 가지의 색의 조합으로 나타낸다. 색의 3원색을 각각 어느정도로 섞느냐에 따라 무지갯빛 색상을 모두 만들어낼 수 있다. 따라서 컬러 이미지는 각 픽셀 포인트마다 Red, Green, Blue, 총 세 가지의 값을 가지므로 **`(14x14)`** 크기의 2차원 배열을 Red 용, Green 용, Blue 용 총 세 장 사용해 **`(14x14x3)`**의 3차원 배열로 표현한다. 물론 흑백 이미지라면 RGB가 필요없이 흑과 백의 밝은 정도를 0~255 사이의 수치로만 표현하면 되므로 **`(14x14)`** 한 장, 즉 2차원 배열로 표현된다.
# 3. 세 번째 표현 방법은 **표**로 나타내는 것이다. 해당 데이터가 가지고 있는 '특징(Feature)'을 각 열에 나타내고, 해당 열마다 어떤 값을 가지는지를 표 형식으로 나타낼 수 있다. 다만, 표 형식으로 나타낼 때에는 먼저 해당 데이터를 '어떤 특징(Feature)으로 나타낼 것인지', 즉 각 열의 내용을 적합한 것들로 정의하는 과정이 필요하다. 위와 같은 데이터를 표로 나타내려고 할 때 '손가락의 길이'와 같은 열이 있으면 안될 것이다. 즉, 데이터를 표로 나타내기 위해서는 사람이 개입해야 한다.
# 4. 마지막 표현 방법은 **카테고리**이다. 카테고리는 머신러닝에서 주로 '예측하고자 하는 값'으로 사용되는 것이기도 하다. 데이터를 카테고리로 표현하려면 '어떤 카테고리 공간이 있는지'와 '그 중 어떤 카테고리에 속하는지'를 정하는 과정이 필요하다. 즉, 카테고리 공간이 **`['무궁화', '수국', '진달래', '카네이션']`**이라면 그 중 '무궁화'라는 알맞은 카테고리로 표현할 수 있다. 하지만 만약 카테고리 공간이 **`['판다', '호랑이', '거북', '강아지']`**로 되어 있다면 그 안에서 아무리 잘 선택해봐야 '판다' 혹은 '호랑이' 정도로 밖에 표현할 수 없다. 즉, 카테고리를 활용한 표현은 사람의 개입이 매우 강하게 들어간다. 사람이 카테고리 공간을 잘 정의해놔야, 해당 데이터가 알맞은 카테고리로 표현될 수 있다.
#
# 위와 같이 네 가지 방법으로 데이터를 표현해 보았다. 이게 대체 무슨 의미가 있길래 이렇게 설명하는 걸까?
#
# 위의 네 가지 표현 방법은 언뜻 보기에는 아무런 관련이 없어보일 수 있지만, 사실 아주 강력한 **계층적(Hierarchical)** 인 관계를 갖고 있다.<br>
# 무슨 말인고 하니, 1번부터 4번으로 갈수록 **사람의 개입**이 강하게 들어가는 표현이라는 것이다.
#
# 다음과 같이 나타낼 수 있다.
#
# <img src="./image/flower3.jpg" />
#
# 위에 있는 분자 형태와 이미지의 표현은 **`Raw`**한 **`Sensory`**한 표현이라고 할 수 있다. 특별한 가공이 들어가지 않은 날것의, 그저 감각기관만으로 받아들일 수 있는 데이터이다.
#
# 반면, 표와 카테고리의 아래쪽 표현들은 **`Abstract`**하고 **`Internal`**한 표현들이다. 사람의 개입이 강하게 들어가고, 그렇기 때문에 더 추상적이고 함축적인 내재적 표현을 할 수 있게 된다.
#
# 다시 조슈아 벤지오의 딥러닝에 대한 정의를 상기해보자.
#
# > ***Deep learning is inspired by neural networks of the brain to build learning machines which discover rich and useful internal representations, computed as a composition of learned features and functions.***
#
# * 뇌의 신경 구조로부터 영감을 받아 신경망 형태로 설계된 딥러닝의 목표는, '합성된 함수를 학습시켜서 풍부하면서도 유용한 '내재적 표현'을 찾아내는 machine을 구축하는 것'이다.

# %% [markdown]
# 딥러닝의 목표는 학습된 함수를 사용하여 유용한 **`internal representations`**, 즉 내재적 표현을 뽑아내는 것이다. 위에서 본 '표'나 '카테고리'와 같은 추상적이고 내재적인 표현들을 사람의 개입 없이 딥러닝만으로 나타낼 수 있는 모델을 학습시키는 것이 궁극적인 목표라고 할 수 있다.
#
# 물론 딥러닝 모델이 아무리 잘 학습되어도 '꽃잎의 색'은 분홍색이고, '꽃잎의 개수'는 5개라는 표를 내뱉진 않는다. 다만, 이미지 영역에서 많이 쓰이는 딥러닝 모델들은 이미지를 입력받으면 신경망 내부의 복잡한 함수 연산을 통해 최종적으로 피처(Feature), 혹은 표현(Representation)이라고 할 수 있는 '숫자로 이루어진 벡터'를 추출해낸다.
#
# 아래 이미지는 이미지 처리에 많이 쓰이는 VGG16이라는 모델이 이미지를 입력받아 처리하는 과정을 나타낸 그림이다.
#
# <img src="./image/vgg.jpg" />
#
# [https://www.researchgate.net/figure/Fig-A1-The-standard-VGG-16-network-architecture-as-proposed-in-32-Note-that-only_fig3_322512435](https://www.researchgate.net/figure/Fig-A1-The-standard-VGG-16-network-architecture-as-proposed-in-32-Note-that-only_fig3_322512435)
#
# 위와 같이 VGG16 모델은 얇은 이미지 한 장을 입력받으면 내부 연산을 거치면서 데이터를 각기 다른 크기의 3차원 배열 형태로 표현하다가, 최종적으로 **`(1x1x1000)`**과 같이 1,000개의 숫자로 이루어진 1차원 형태의 벡터를 출력한다. VGG16은 이미 학습이 잘 되어있는 네트워크이므로, 이미지를 입력받은 후 그 안에 내재되어 있는 특성 혹은 표현을 의미 있는 1,000개의 숫자로 잘 나타낼 수 있다.
#
# 만약 입력되는 이미지의 크기가 **`(224x224x3)`**이었다면 약 15만 개의 숫자로 데이터가 표현된다. 이를 잘 학습된 딥러닝 네트워크에 먹이면 단 1,000개의 숫자만으로 그 이미지의 내재된 특성들을 모두 표현할 수 있게 되는 것이다. 놀랍게도 사람이 가르쳐준 규칙 없이도 말이다! (물론 네트워크를 학습시키는 것은 사람의 몫이다. 하지만 한 번 잘 학습시켜 놓으면 몇 천, 몇 만 장의 이미지를 수 분 내에 처리할 수 있다는 것이 중요한 포인트이다)
#
# 데이터의 '내재된 표현(Internal Representation)'이라는 것이 무엇인지, 그리고 데이터로부터 '좋은 표현(Good Representation)'을 추출해낸다는 것의 의미는 무엇인지 와닿을 것이다.

# %% [markdown]
# __데이터의 내재된 표현이란 무엇이고, 데이터로부터 좋은 표현을 추출해낸다는 것은 무슨 뜻일까? 그리고 이는 어떻게 수행될 수 있을까?__
#
# - 데이터의 내재된 표현이란, 그 데이터가 담고 있는 정보의 총체, 혹은 함의를 나타내는 표현을 말한다. 다만, raw한 sensory 데이터는 그 자체로는 중요한 의미를 담지 못하고 있을 수 있다. 마치 이미지를 멀리서 보면 강아지가 보이지만, 각 픽셀 하나하나의 값들은 강아지와 직접적인 연관이 없는 것과 같다.
# - 이러한 맥락에서 데이터로부터 표현을 추출해낸다는 것은 데이터 안에 내재되어 있는, 추상적인 표현을 추출한다는 것을 의미한다. 강아지가 찍힌 이미지에서 좋은 표현을 추출해내려면 픽셀 하나하나의 값으로부터 '강아지'라는 의미를 담고 있는 벡터를 추출해낼 수 있어야 할 것이다.
# - 딥러닝의 본질은 이렇게 데이터로부터 내재된 표현을 추출해내는 것이며, 이는 모델을 Gradient Descent 기반의 학습으로 수행할 수 있다. 물론 더 뛰어난 모델을 얻기 위해서는 모델의 구조나 최적화 기법 등의 세부적인 요인들을 연구하는 것이 필수적이다.
#
# 이러한 맥락에 의해 딥러닝을 'Representation Learning'이라고 칭하기도 한다. **데이터의 표현을 학습한다는 것**, 특히 사람이 가공하지 않은, 이미지나 자연어 같은 '날 것의' 데이터를 입력하면 알아서 **그 안에 내재된 표현을 추출한다는 것**, 이것이 바로 딥러닝이 추구하는 목표의 본질이다!

# %% [markdown]
# ## 4. 딥러닝을 관통하는 철학 (1) 행동주의

# %% [markdown]
# ### ***조금 더 파고들어보자, 딥러닝을 관통하는 철학 속으로***
# ---
#
# 딥러닝의 목표는 데이터의 내재된 표현을 잘 추출하는 것이라는 점을 알았다.
#
# 그렇다면 이러한 문제의식은 어디서 왔을까? 조금 더 깊은 철학으로 들어가보겠다.
#
# 딥러닝의 본질에 대해 논하려면 'Connectionism(연결주의)'이라고 불리는 인지과학의 한 학파로 거슬러 올라가야 한다. 인지과학은 인간의 지능을 자극과 반응의 관계로만 설명하던 행동주의 심리학에 반발하면서 등장한 학문이다.
#
# 연결주의와 인지과학, 행동주의.. 이게 다 무슨 이야기일까! 천천히 하나씩 살펴보자.
#
# > ***행동주의: 학습된 행동은 자극의 반복으로 만들어진다***
#
# **행동주의**는 인간의 지능이 **'자극 → 행동'** 과정의 반복으로 만들어진다고 주장한다.
#
# <img src="./image/havi.jpg" />
#
# 행동주의에 관한 내용을 다음 글로 아주 간단히 읽어보겠다.
#
# * **[나무위키 - 행동주의](https://namu.wiki/w/%ED%96%89%EB%8F%99%EC%A3%BC%EC%9D%98)**
#
# __행동주의란 무엇인가? 행동주의는 인간의 내면이 선천적이라고 주장하는가, 아니면 후천적이라고 주장하는가?__
#
# - 행동주의는 심리학을 과학적으로 접근하고자 하는 시도를 가진 분야로, 철저하게 경험적이고 실증적으로 인간의 내면을 접근하고자 하였다.
# - 따라서 무의식과 같이 관찰될 수 없는 것을 배제하였으며, 인간의 행동은 자극으로부터 직접적으로 만들어진다고 주장하였다.
# - '자극 → 행동'의 흐름에 따라, 인간의 지능 및 내면은 살아가면서 받는 자극으로 형성되는 후천적인 것이라고 주장하였다.
#
# 행동주의는 인간, 혹은 인간뿐만 아니라 모든 생명체의 지능은 반복되는 자극에 따라 형성된다고 주장하였다.<br>
# 행동주의를 연구한 대표적인 학자 스키너(Skinner)는 비둘기에게 적절한 보상을 줌으로써 탁구를 학습시키는 것이 가능하다는 것을 실험으로 보여주었다.
#
# 아래는 실제 스키너가 진행한 실험의 영상이다.
#
# [![Pigeon Ping Pong](http://img.youtube.com/vi/vGazyH6fQQ4/0.jpg)](https://youtu.be/vGazyH6fQQ4?t=0s)
#
# 두 마리의 비둘기를 핑퐁 테이블 앞에 두고서 공을 놓치지 않고 받아내면 아래에서 먹이를 먹을 수 있도록 함으로써 비둘기에게 탁구를 학습시켰다.
#
# 이렇게 생명체가 외부에서 받는 자극으로 인해 학습되는 과정을 '조작적 조건화(Operant Conditioning)'라고 한다. 다음 두 가지 글에서 '조작적 조건화'를 조금 더 자세히 알아보겠다.
#
# * **[조작적 조건화](https://ko.wikipedia.org/wiki/%EC%A1%B0%EC%9E%91%EC%A0%81_%EC%A1%B0%EA%B1%B4%ED%99%94)**
# * **[인간의 행동을 '조작'할 수 있다면? '스키너의 상자'(Skinner Box)](http://www.edupolnews.com/news/articleView.html?idxno=11676)**
#
# __스키너의 상자가 무엇인가? 스키너의 상자를 통해 어떤 실험이 진행되었나?__
#
# - '스키너 상자(Skinner Box)'는 동물행동을 연구하기 위해 고안된 장치로, 쥐가 먹이를 얻기 위해 누를 수 있는 레버나 막대가 달려 있고, 통풍과 방음설비가 된 상자로 구성된다.
# - 레버를 누르면 먹이를 받을 수 있는데, 쥐는 처음에는 이러한 사실을 알지 못하지만 레버를 누르고 먹이를 받는 경험을 여러 번 하게 될 경우 이를 학습하게 되며, 먹이를 받기 위해 레버를 누르는 행동을 할 수 있게 됨을 보였다.
# - 이렇게 어떤 행동을 한 뒤에 생명체가 원하는 것을 제공하는 것을 강화(Reinforcement)라고 한다.
#
# 이렇게 행동주의는 생명체가 학습하는 과정을 단순하게 자극과 행동의 반복으로 이루어지는 것이라고 설명한다.
#
# 이 중 생명체가 자신에게 유리한 결과를 가져다주는 행동을 알게 된다면 그 행동의 빈도를 높인다는 '강화이론'은, 머신러닝의 방법론 중 '강화학습(Reinforcement Learning)'의 근간이 되는 이론이기도 한다. 강화학습은 실제로 특정 행위자를 학습시키기 위해 행위자가 하는 행동이 얼마나 좋았는지에 대한 척도인 '보상'을 부여하고, 행위자는 그 보상을 높이기 위해 자신의 행동을 교정하면서 학습해나가게 된다.

# %% [markdown]
# ## 5. 딥러닝을 관통하는 철학 (2) 인지주의

# %% [markdown]
# ### ***인지주의: 인간은 비둘기와는 다르다! 정보를 처리하는 '의식'이 있다***
# ---
# 하지만 행동주의는 인간의 내면을 지나치게 단순화했다는 비판을 받았다. 단순히 반복되는 자극에 따라 행동을 '강화'함으로써 학습되는 것이 아니라, 인간의 뇌 안에서 기억, 주의 등의 일련의 정보처리 과정을 거친 후 행동을 만들어낸다는 주장이 노암 촘스키(Noam Chomsky)에 의해 새롭게 제기되었다. 이렇게 행동주의를 반대하며 제기된 학문이 바로 인지심리학이다.
#
# 다음 글에서 인지심리학이 무엇인지 간략하게 읽어보겠다.
#
# * **[나무위키 - 인지심리학](https://namu.wiki/w/%EC%9D%B8%EC%A7%80%EC%8B%AC%EB%A6%AC%ED%95%99?from=%EC%9D%B8%EC%A7%80%EC%A3%BC%EC%9D%98)**
#
# __인지주의는 행동주의와 어떻게 다르며, 어떠한 새로운 관점을 제시하였을까?__
#
# - 인지주의는 '자극 → 행동'의 관계만 설명하던 행동주의에 대해 반발하며 '자극 → (정보처리) → 행동' 의 관점을 제시하였다.
# - 인간의 행동이 단순히 자극으로부터 만들어진다는 주장으로 인간의 '의식'을 부정했던 행동주의와 달리, 인지주의는 인간이 자극을 받은 후 내면에서 정보를 처리하고 가공하는 의식이 존재함을 주장하였다.
# - 즉, 인지심리학은 인간의 마음을 일종의 정보 처리 체계로 보고 접근하고, 이에 따라 인간의 뇌가 정보를 처리하는 과정에 대해 관심을 가지며 신경과학이라는 새로운 분야를 만들어냈다.
#
# 인지주의는 자극과 반응 사이에 있는 '정보처리' 과정에 관심을 두었다. 생명체의 지능은 단순히 어떤 행동을 자극에 맞추어 '강화'하는 것을 넘어서서, 자극을 받아 반응을 하기까지 복잡한 알고리즘을 통해 정보를 처리하는 것이라고 생각한 것이다. 다음과 같은 그림으로 나타낼 수 있다.
#
# <img src="./image/inji.jpg" />
#
# 이런 블랙박스 정보 처리는 인간의 어떤 부분에서 일어날까?
#
# 바로 우리의 뇌이다. 우리는 분명 눈 앞에 어떤 상황이 벌어진다거나, 혹은 물리적으로 신체에 어떤 자극이 왔을 때 머릿속으로 여러 가지 생각을 한다. 행동주의에 따르면 우리가 외부에서 자극을 받았을 때 단순히 이전에 받은 보상의 경험에 따라서만 행동한다. 하지만 그런 관점으로는 지금 우리가 이 글을 읽으면서 머릿속으로 이해를 하거나, 혹은 여러 가지 관련된 상상을 하는 것에 대해 설명하지 못한다.

# %% [markdown]
# ## 6. 딥러닝을 관통하는 철학 (3) 연결주의

# %% [markdown]
# ### *연결주의: 정보처리는 뇌에 있는 수많은 뉴런의 연결고리를 통해 이루어진다*
# ---
# 인지주의에는 위와 같이 자극으로부터 행동을 만들어내는 정보처리 과정을 설명하는 모형이 몇 가지 있다. 기호 모형(Symbolic modeling) 혹은 연결주의 모형(Connectionism) 등이 있다.
#
# 이들은 페드로 도밍고스(Pedro Domingos)가 쓴 '마스터 알고리즘'이라는 책에서 소개되는 머신러닝의 다섯 종족과도 연결된다. 다섯 종족은 기호주의자, 연결주의자, 진화주의자, 베이즈주의자, 그리고 유추주의자이다. 각각에 대해서는 오늘 소개하고자 하는 내용을 벗어나므로 자세히 다루지는 않겠지만, 머신러닝과 딥러닝의 철학에 대해 관심이 있다면 아래 책을 읽어보시는 것을 추천한다. 수학적 접근을 배제하고, 이야기로 풀어나가는 점이 인상적인 책이다.
#
# <img src="./image/ma.jpg" />
#
# **[http://www.yes24.com/Product/Goods/29386373](http://www.yes24.com/Product/Goods/29386373)**
#
# 인지주의에는 자극으로부터 반응을 하기까지 정보를 처리하는 과정을 수행하는 모형이 몇 가지 있다. 그 중 우리가 주목해야 할 것은 바로 연결주의(Connectionism) 이다. 연결주의는 몇 백억 개의 뉴런이 연결되어 있는 뇌의 형태처럼, 수많은 신호들이 연결된 일련의 과정에 따라 정보가 처리된다고 본다.
#
# 다음 글로 연결주의에 대해 조금 더 자세히 읽어보겠습니다.**
#
# **[위키백과 - 연결주의](https://ko.wikipedia.org/wiki/%EC%97%B0%EA%B2%B0%EC%A3%BC%EC%9D%98)**
#
# __연결주의에 따르면 지능체는 어떻게 학습을 진행해 나가는가?__
#
# - 연결주의는 자극으로부터 반응을 하기까지의 과정에서 뉴런과 같이 연결되어 있는 모형이 정보를 처리해 나간다고 설명한다.
# - 이에 따라 연결주의의 지능체는 처음에는 '백지' 상태이며, 다수의 사례를 주고 '경험'함으로써 스스로 천천히 '학습'해 간다.
# - 즉, 학습된 내용은 연결된 뉴런 자체에 저장되어 있으며, 외부에서 자극을 받음에 따라 그 연결 형태가 바뀌면서 학습된 내용이 바뀌어간다.
#
# 앞선 인지주의를 관통하는 문제의식은 '자극을 받아 반응을 하기까지, 생명체 내부에서 정보가 어떻게 표현되거나 처리되기에 "지능"이라는 현상이 나타나는가?'라고 할 수 있다. 이 질문에서 '정보를 표현하거나 처리하는 방법'에 대해 답하기 위한 모형 중 하나가 연결주의인 것이다.
#
# **딥러닝**은 바로 이 연결주의를 따른다. <br>
# 딥러닝은 뇌의 뉴런이 얽히고 섥혀서 연결되어 있는 모양을 본딴 '인공 신경망'을 모델로 가진다. 신경망은 자극(input)을 받아 내부에서 일련의 정보처리 과정을 거친 후 반응(output)을 한다. 신경망 내부에서는 하나의 데이터를 여러 형태로 바꾸어가며 표현(representation)을 해 나가다가, 최종적으로 우리가 의도한 형태의 데이터를 출력한다.
#
# 이렇게 인지주의와 연결주의의 철학과 문제의식을 계승하였으니 딥러닝의 궁극적인 목표는 생명체가 데이터를 입력받았을 때 내부에서 정보를 처리하고 표현하는 메커니즘을 알아내는 것이라고 할 수 있다.
#
# 딥러닝에 담긴 철학을 이야기하기 위해 여러 가지 이야기를 돌아왔다. 다음 단계부터는 딥러닝이 사용하는 신경망 모델의 본질에 대해 살펴보겠다.

# %% [markdown]
# ## 7. 신경망의 본질 (1) 개요

# %% [markdown]
# ### ***'신경망', 그 본질에 대하여***
#
# 딥러닝은 데이터를 입력받으면 일련의 정보 처리 과정을 통해 여러 가지 방법으로 데이터를 표현하다가 원하는 형태로 출력하는 것을 목표로 한다는 것을 알았다.
#
# 그림으로 나타내면 다음과 같다.
#
# <img src="./image/nn.jpg" />
#
# 특히 여기서 딥러닝은 연결주의 모형에 따라, 블랙박스에 해당하는 모형을 뇌와 닮은 신경망으로 채택하였다. 다시 표현해 보자면 다음과 같다.
#
# <img src="./image/nn2.jpg" />
#
# 어떤 입력을 받으면 신경망 내부에서 처리 과정을 거쳐 출력을 만들어낸다.
#
# 입력을 받아 출력을 한다는 것, 우리에게 매우 익숙한 형태이다.
#
# <img src="./image/funct.jpg" />
#
# 중고등학생 때 지겹도록 배운 **함수**와 같다!
#
# 신경망은, 다른 이름으로 말하자면 **함수**라고 할 수 있다. 매우 당연하고 간단한 이야기라고 생각할 수 있다. 하지만 신경망을 뇌와 비슷한 형태를 모사해 아주 복잡한 형태를 가진, 미지의 무언가라고 생각하기보다는 입력을 받은 후 내부에서 일련의 연산 과정을 거쳐 출력을 내는 거대한 함수로 보는 것도 앞으로 많은 딥러닝 기법을 이해할 때 도움이 될 수 있다.

# %% [markdown]
# ## 8. 신경망의 본질 (2) 수학과 프로그래밍의 "함수"

# %% [markdown]
# ### ***수학에서의 함수와 프로그래밍에서의 함수, 다르지 않다***
#
# ---
#
# 조금 더 엄밀하게 고민해보자.
#
# 우리는 고등학생 때까지 일차, 이차, 삼차 함수와 같은 다항 함수뿐만 아니라, 지수 함수와 로그함수, 삼각함수 등 어마무시하게 다양한 함수들을 배웠다.<br>
# 이 모든 것들의 상위 집합인 '함수'는 수학적으로 다음과 같이 표현된다.
#
# $$y = f(x)$$
#
# 여기에서 $x$는 입력되는 값, 그리고 $y$는 출력되는 값으로, 조금 전에 봤던 이미지처럼 $x$가 $f$라는 박스에 들어가 $y$라는 결과물로 출력된다는 것을 식으로 나타낸 것이다.
#
# 반면, 우리가 지금 배우고 있는 프로그래밍에도 함수의 개념이 있다. 파이썬으로 함수를 구현하자면 다음과 같다.

# %%
def f(x):
    y = 3 * x + 2
    return y

# %% [markdown]
# 위에서 구현된 함수 f(x)는 (f(x) = 3x+2) 라는 아주 간단한 일차 함수를 구현한 것이다.
#
# 다음과 같이 사용하면 수학에서의 표기와 동일한 형태로 프로그래밍에서의 함수를 사용할 수 있다.

# %%
x = 5

y = f(x)   # 3 * 5 + 2 = 17
y
# Out:
# 17

# %% [markdown]
# 여기서 한번, (f(x) = x^2 + e^{x+1}) 를 파이썬 함수로 구현하고, (f(5)) 값을 계산해보자. ((f(5)=428.43) 정도의 값이 나와야 한다.)<br>
# (hint. **`exp`** 함수는 파이썬에 내장된 **`math`** 라이브러리 안에 있다.)

# %%
import math

def f(x):
    y = x ** 2 + math.exp(x+1)
    return y

x = 5

y = f(x)  
y
# Out:
# 428.4287934927351

# %% [markdown]
# 어떤가? 수학에서 말하는 함수와, 프로그래밍에서 말하는 함수는 그 본질이 전혀 다르지 않다.
#
# 두 가지 다 아래와 같이 입력, 내부 연산, 출력이라는 형태를 가진다.
#
# <img src="./image/funct2.jpg" />
#
# 당연한 이야기들은 이쯤에서 마무리하겠다.

# %% [markdown]
# ## 9. 신경망의 본질 (3) 함수의 역할 - 상
#
# 지금까지 확인한 함수의 본질을 이해했다면, 이번에는 함수의 역할을 다양하게 이해해 볼 차례이다. 다음과 같은 세 가지 정도로 함수의 역할을 정의할 수 있다.<br>
# (사실 아래의 세 가지는 모두 함수의 본질에서 벗어나지 않는다. 다만, 보다 다양한 관점에서 함수를 이해해 보기 위한 시도라고 할 수 있다.)

# %% [markdown]
# ### ⅰ. 함수의 역할 첫 번째, Relation: x와 y의 관계를 나타낼 수 있는 도구
# ---
# 먼저 함수 $f$ 는 입력인 $x$와 $y$의 관계를 나타낼 수 있는 도구라고 할 수 있다.
#
# 예를 들어 다음과 같은 함수의 경우, $y$는 $x$가 증가하면 $x$ 증가량의 두 배로 커지는 관계를 갖는다.
# $$y = 2x$$
#
# 그래프로 그려보면 다음과 같은 관계가 있다는 것이 명확하게 나타난다.
#
# <img src="./image/graph.jpg" />
#
# 그래서 "$y$는 $x$의 함수이다"라는 표현은 아주 중요한 함의를 가지고 있다.
#
# $y$가 $x$의 함수라는 말은,
#
# * $y$는 $x$의 변화에 종속적이다. 즉 $x$가 변하면 그 변화하는 정도에 따라 $y$가 변하게 된다.
# * $x$가 변하는 정도에 따라 $y$가 얼마나 변하는지는 $x$와 $y$의 간 함수의 형태(다항식인지, 삼각함수인지, 혹은 신경망인지 등)로 결정된다.
#
# 라는 뜻이다. 함수는 $x$와 $y$ 사이에 매우 강한 종속적 관계를 가지게 한다.
#
# __"y는 x의 함수이다"라는 말은 어떤 함의를 가지고 있는가?__
#
# - y는 x의 변화에 종속적이다, 즉 x가 변하면 그 변화하는 정도에 따라 y가 변하게 된다.
# - x가 변하는 정도에 따라 y가 얼마나 변하는지는 x와 y의 함수 형태(다항식인지, 삼각함수인지, 혹은 신경망인지 등)로 결정된다.

# %% [markdown]
# ### ⅱ. 함수의 역할 두 번째, Transformation: xx를 변환해주는 도구
# ---
# 함수의 역할 두 번째는 $x$를 변환해주는 도구라고 할 수 있다.
#
# 함수를 변환(Transformation)의 관점에서 볼 때, 우리가 필수적으로 이해해야 하는 개념은 바로 선형 변환(Linear Transformation)이다.
#
# 다음 영상을 한번 보겠다.<br>
# 10분의 짧은 영상이지만, 선형성과 행렬, 그리고 변환으로서의 함수에 대한 통찰이 매우 풍부한 영상이다.
#
# [![Linear Transformation](http://img.youtube.com/vi/kYB8IZa5AuE/0.jpg)](https://youtu.be/kYB8IZa5AuE?t=0s)
#
# __영상의 약 30~40초 구간에서 Linear Transformation과 어떤 개념을 연결짓는다. 이 개념은 무엇인가?__
#
# - Linear Transformation이 행렬곱 연산과 연관되어 있다고 말한다.
# - 영상에서는 행렬곱 연산을 단순히 곱셈과 덧셈으로 이루어지는 계산이 아닌, 선형 변환의 관점에서는 어떤 의미를 갖는지를 설명하고자 한다.
#
# __약 50초~1분 구간에서 Transformation을 어떤 개념과 연결지어 설명하는가? 그리고, 선형대수학에서는 어떤 것을 입력받아 무엇을 출력한다고 하는가?__
#
# - Transformation은 function(함수)의 fancy한 용어라고 설명한다. (즉, 같은 용어이다.)
# - 특히, 선형대수학에서는 이러한 '변환' 역할을 하는 함수가 변환하기 전의 vector를 입력받아 변환된 후의 vector를 출력한다.
#
# __Transformation은 2차원 평면에서 어떤 변화를 만들어내는가?__
#
# * 2차원 평면에서의 Transformation은 축(grid)을 '옮기는(move)' 역할을 한다. 어떤 변환을 하냐에 따라 수직과 수평이었던 2차원 축을 옮길수도, 휘게 할 수도, 꼬이게 할 수도 있다.
#
# __Transformation 중 특히 Linear Transformation이 되려면 두 가지 조건을 만족해야 한다고 한다. 두 가지는 무엇인가?__
#
# - 첫 번째, 변환된 축은 여전히 '직선' 형태를 띄어야 한다. 즉, 휘거나 구부러지면 안된다.
# - 두 번째, 변환 후에도 원점(origin)은 이동하지 않아야 한다. 즉, 원점은 그대로여야 한다.
#
# 영상에서는 선형 변환이 어떻게 이루어지는지 굉장히 직관적으로 설명한다.
#
# 먼저 아래 이미지는 변환 전의 벡터이다. 익히 알고 있듯이 수직을 이루고 있는 $x$축과 $y$축이다. 아래에 나타난 ${\hat{\imath}}$ 벡터와 $\hat{\jmath}$ 벡터는 각각 $x$축의 단위벡터와 $y$축의 단위벡터이다.
#
# 변환하고자 하는 벡터는 $\overrightarrow{\mathbf v} = -1 {\hat{\imath}} + 2 \hat{\jmath}$ 로, 좌표에서는 $\begin{bmatrix} -1 \\ 2 \end{bmatrix}$의 점을 가리키는 벡터이다.
#
# <img src="./image/vid1.jpg" />
#
# [https://www.youtube.com/watch?v=kYB8IZa5AuE](https://www.youtube.com/watch?v=kYB8IZa5AuE)
#
# 여기에서 좌표축을 아래와 같이 변환하면 $\overrightarrow{\mathbf v}$도 다음과 같이 바뀐다.
#
# * ${\hat{\imath}} : \begin{bmatrix} 1 \\ -2 \end{bmatrix}$로 변환
# * ${\hat{\jmath}} :\begin{bmatrix} 3 \\ 0 \end{bmatrix}$으로 변환
#
# $\overrightarrow{\mathbf v} = -1 × ( Transformed \; {\hat{\imath}}) + 2 × ( Transformed \; {\hat{\jmath}} )$ 이며, 아래와 같이 행렬 연산으로 구할 수 있다.
#
# <img src="./image/vid2.jpg" />
#
# [https://www.youtube.com/watch?v=kYB8IZa5AuE](https://www.youtube.com/watch?v=kYB8IZa5AuE)
#
# 식으로 나타내면 다음과 같다.
#
# <img src="./image/vid3.jpg" />
#
# 실제로 위의 이미지에서 변환된 벡터인 $\overrightarrow{\mathbf v}$는 $\begin{bmatrix} 5 \\ 2 \end{bmatrix}$ 위치를 나타내고 있다.
#
# 여기까지 행렬 곱 연산이 좌표축의 변환이라는 것을 이해했다면, 아래와 같은 식이 $\begin{bmatrix} x \\ y \end{bmatrix}$라는 벡터를$\begin{bmatrix} a & b \\ c & d \end{bmatrix}$행렬을 이용해 변환하게 된 벡터라는 것이 보일 것이다.
#
# <img src="./image/vid4.jpg" />
#
# [https://www.youtube.com/watch?v=kYB8IZa5AuE](https://www.youtube.com/watch?v=kYB8IZa5AuE)
#
# 결국 $\mathbf x = \begin{bmatrix} x_1 \\ x_2 \end{bmatrix}$의 벡터일 때, 행렬곱을 행하는 함수로
#
# $f({\mathbf x}) = \begin{bmatrix} a & b \\ c & d \end{bmatrix} \begin{bmatrix} x_1 \\ x_2 \end{bmatrix} = \begin{bmatrix} ax+by \\ cx+dy \end{bmatrix} = \begin{bmatrix} y_1 \\ y_2 \end{bmatrix} = \mathbf y $ 라는 변환을 할 수 있고,
#
# 이 때 $f(\mathbf x) = \mathbf y$ 에서 $f(x)$라는 함수는 $\mathbf x$라는 벡터를 $\mathbf y$ 라는 벡터로 변환해 주는 도구라고 할 수 있다.

# %%
import numpy as np

def linear_transformation(X, A):
    transformed_vector = np.matmul(X, A)
    return transformed_vector

# %% [markdown]
# 아래에서는 한번 **`linear_transformation()`** 함수를 활용해 위의 그림과 동일한 변환을 구현해보자.
#
# $[−1,2]$의 벡터가 $\begin{bmatrix} 1 & -2 \\ 3 & 0 \end{bmatrix}$ 변환을 통해 $[5,2]$의 벡터로 옮겨지는 결과를 나타내면 된다.

# %%
X = np.array([-1, 2])

A = np.array([[1, -2],
              [3, 0]])

linear_transformation(X, A)
# Out:
# array([5, 2])

# %% [markdown]
# ## 10. 신경망의 본질 (4) 함수의 역할 - 하

# %% [markdown]
# ### **ⅲ. 함수의 역할 세 번째, Mapping: x의 공간에서 y의 공간으로 매핑 해주는 도구**
#
# ---
#
# 마지막으로 함수를 $x$의 공간에서 $y$의 공간으로 매핑(Mapping)해주는 도구라는 관점에서 접근해 보겠다.
#
# 사실 바로 전에 본 변환(Transformation)의 관점 또한, 하나의 벡터를 다른 벡터로 매핑하는 것이라고 볼 수 있다. 다만, 이번에는 조금 더 다양한 매핑을 살펴보려고 한다.
#
# 바로 함수의 입력과 출력이 스칼라(Scalar)인지, 벡터(Vector)인지에 따라 구분해 보는 것이다.
#
# 스칼라와 벡터는 아마 친숙한 개념일 것 같다. 다음 글들을 보고 간단히 알아보자.
#
# * [위키백과 - 스칼라(Scalar)](https://ko.wikipedia.org/wiki/%EC%8A%A4%EC%B9%BC%EB%9D%BC_(%EC%88%98%ED%95%99))
# * [위키백과 - 벡터(Vector)](https://ko.wikipedia.org/wiki/%EB%B2%A1%ED%84%B0_(%EB%AC%BC%EB%A6%AC))
#
# __스칼라와 벡터.__
#
# - 스칼라는 '크기'만 가지고 '방향'은 가지지 않는 양이다. 주로 단 하나의 숫자로 표현한다.
# - 벡터는 '크기'와 '방향'을 두 가지 가지는 양이다. 주로 여러 개의 숫자로 표현되며, 좌표 상에서 길이와 방향을 가지는 화살표로 표현한다.
#
# 이러한 배경에서, 함수는 아래 세 가지 방법을 통해 입력을 출력으로 매핑할 수 있다.

# %% [markdown]
# #### ✓ One-to-One
#
# One-to-one 매핑은 입력값 $x$와 출력값 $y$가 모두 스칼라인 경우이다. 단 하나의 값을 입력했을 때, 단 하나의 값만 나오게 된다.
#
# <img src="./image/121.jpg" />
#
# One-to-one의 예제를 살펴보자.
#
# <img src="./image/121.png" />
#
# 위와 같이 키 값이 있을 때, 몸무게를 예측하는 함수를 만든다면 One-to-One에 해당한다.<br>
# 키 값을 입력받으면 일정한 연산을 통해 몸무게를 출력하는 함수를 만들어볼 수 있다. 다음과 같은 그림으로 나타낼 수 있다.
#
# <img src="./image/1212.jpg" />
#
# $f$를 아주 간단한 선형 방정식으로 채택한다면, 다음과 같은 식으로 쓸 수 있다.
#
# $$f(x) = wx + b = \hat y$$
#
# 하지만 사람의 키와 몸무게는 단순한 일차함수의 관계를 갖지 않는다. 몸무게는 키뿐만 아니라 보다 복잡한 요인들로 인해 결정된다. <br>
# 그러므로 위와 같은 단순한 일차 함수는 키 값을 입력받았을 때 정답값이 아닌, 예측값을 출력할 것이다. 이러한 예측값은 $y$ 위에 모자(hat)를 씌워서 $\hat y$ 로 표기한다.
#
# __One-to-One의 다른 예시__
#
# * 맥북이 사용된 연수를 입력받았을 때, 그 중고가를 출력하는 함수 등

# %% [markdown]
# #### ✓ Many-to-One
#
# Many-to-One은 여러 가지의 정보를 입력받아 하나의 값을 출력하는 경우이다.
#
# 이 경우 함수는 다음과 같이 벡터인 $x$를 입력받아 스칼라인 $y$를 출력하는 형태로 나타낼 수 있다. 이때 일반적으로 벡터는 볼드체로 $\mathbf x$와 같이 나타낸다.
#
# <img src="./image/m2o.jpg" />
#
# 위에서 이야기했던 예제를 발전시켜 다음과 같은 상황을 생각해볼 수 있다.
#
#
# <img src="./image/m2o2.png" />
#
# 사람에 대한 정보가 키만 있었던 이전 예시와 달리, 체지방, 골격근 등 보다 많은 데이터를 입력받으면 몸무게를 예측하기 더 용이해질 것이다.
#
# 그림으로는 다음과 같이 나타낼 수 있다.
#
# <img src="./image/m2o2.jpg" />
#
# 이제 함수가 이전보다 많은 데이터를 입력받고 있죠. 벡터를 입력받아서, 단 하나의 스칼라를 출력하는 형태이다.
#
# 사족을 덧붙이자면, 일반적으로 머신러닝/딥러닝에서는 이러한 문제를 회귀(Regression) 문제라고 한다. 더 정확하게 회귀 문제란 입력 데이터가 몇 개인지는 상관없이, 단 하나의 연속된 실수 스칼라값을 맞추는 문제를 일컫는다. 그러니까 위에서 이야기했던 One-to-One 문제도 회귀 문제라고 할 수 있다. 정확히는 One-to-One의 경우 입력되는 변수가 단 하나이기 때문에 단변량 회귀(Univariate Regression), 그리고 Many-to-One의 경우에는 입력 변수가 여러 개이므로 다변량 회귀(Multivariate Regression)라고 한다.
#
# __Many-to-One의 다른 예시__
#
# * 맥북이 사용된 연수, RAM 용량, CPU 사양, 화면 크기 등을 입력받았을 때, 그 중고가를 출력하는 함수 등

# %% [markdown]
# #### ✓ Many-to-Many
# 마지막으로 살펴볼 것은 Many-to-Many이다. 입력값도 벡터, 출력값도 벡터인 경우이다.
#
# <img src="./image/m2m.jpg" />
#
# Many-to-Many의 경우에는 조금 재미있는 예제를 떠올려 보겠다.
#
# 요즘 인기가 높은 MBTI를 맞추는 모델이 있다고 생각해보자. (물론 이해를 위한 예시일 뿐, 실제 과학적 내용을 토대로 하고 있는 것은 아니다.)
#
# <img src="./image/m2m2.jpg" />
#
# 보통 우리가 MBTI 검사를 할 때에는 여러 개의 질문이 있는 설문지에 답변을 한다. 그렇다면 위와 같이 성격의 특징 중 '안정을 추구하는 정도', '몽상에 빠지는 빈도' 등과 같은 지표들을 숫자로 체크한 후 모두 모아 벡터 형태로 입력할 수 있다.
#
# 그렇다면 MBTI는 총 4개의 부분에서 E/I, S/N, F/T, P/J를 조합해 네 글자의 결과를 만들어내므로, 네 개의 지표 각각을 0과 1 사이의 숫자로 출력하도록 하여 각각 0에 가까운지, 1에 가까운지에 따라 네 가지의 성향을 결정할 수 있을 것이다.
#
# 여기서 함수는 성격의 여러 가지 특징을 숫자로 표현한 벡터를 입력받은 후 4개의 숫자로 이루어진 벡터를 출력함으로써 MBTI 결과를 만들어내는 것이다. 실제로 아주 많은 사람들의 설문 결과와 성격 유형에 대한 데이터가 있다면 위와 같은 성격 유형 예측 모델을 만드는 것도 가능할 것이다.
#
# 사실 Many-to-Many가 주로 쓰이는 문제는 바로 '분류' 문제이다. 위에서 봤던 회귀 문제와 달리, 여러 개의 카테고리 중 어떤 카테고리에 속하는지를 맞추는 분류 문제는 카테고리 개수로 이루어진 벡터를 출력한다.
#
# <img src="./image/m2m3.jpg" />
#
# 실제로 조금 더 많이 쓰이는 예제를 생각해 보면 위와 같다.
#
# 위와 같이 어떤 식물에 대한 정보가 '꽃잎의 길이', '꽃잎의 개수' 등으로 입력되고 **`[진달래, 국화, 코스모스]`** 세 가지 카테고리 중 하나로 맞추어야 하는 경우, 세 가지 카테고리 각각에 대해 확신하는 정도를 확률 값처럼 출력한다. 분류 문제를 풀 때에는 보통 그림의 오른쪽과 같이 출력되는 벡터를 모두 합하면 1이 되도록 정규화하는 과정을 거친다.
#
# __Many-to-Many의 다른 예시__
#
# * 가로 128픽셀, 세로 128픽셀로 이루어진 (128, 128) 사이즈의 이미지를 입력하면 각 카테고리에 대한 확률 값을 담은 벡터를 출력하는 함수 등
#
# 여기까지 함수를 '관계(Relation)', '변환(Transformation)', '매핑(Mapping)' 세 가지 관점에서 이해해 보았다.
#
# 세 가지 모두 완전히 서로를 배제하는 개념은 아니며, 풀고자 하는 문제에 따라 함수의 역할은 몇 가지가 종합되어 있을 수 있다.<br>
# 중요한 것은 이렇게 다양한 해석을 이해하며 보다 확장된 관점에서 함수를 이해해 보는 것이다.

# %% [markdown]
# ## 11. 신경망의 본질 (5) 함수와 모델
#
# ***우리가 배운 함수와, 앞으로 다룰 '모델'이라는 함수가 다른 점***

# %% [markdown]
# ### **함수와 모델의 차이점**
#
# ---
#
# 함수에 대한 이야기를 마치기 전에 한 가지만 더 짚고 넘어가겠다.
#
# 지금까지 우리가 알고 있는 친숙한 형태의 함수와, 앞으로 받아들일 '신경망', 혹은 신경망 외의 '머신러닝 모델' 등 형태의 함수가 어떻게 다른지 생각해보자.<br>
# (머신러닝/딥러닝에서 데이터를 입력받아 원하는 값을 예측하거나, 원하는 형태로 데이터를 표현하여 출력하는 모든 함수를 '모델'이라고 칭한다.)
#
# 우리가 지금까지 다뤄왔던 함수는 그 형태가 고정되어 있는 경우가 대부분이었다.<br>
# 우리가 지금까지 수학 문제를 풀든, 프로그래밍을 하며 함수를 구현하든 우리가 사용하고자 하는 함수는 정해져 있고, 우리가 해야 할 일은 그 함수의 수식을 찾아내거나, 또는 알맞은 형태로 구현하는 것뿐이었다.
#
# 예를 들어 고등학생 때 공부하던 수학을 떠올려보자.
#
# 우리가 두 점 $(1, 2)$, $(0, 5)$ 를 지나는 이차 함수를 구하는 문제를 푼다면 $f(x) = ax^2 + bx + c$와 같이 함수식을 미지수와 함께 두고 점을 대입하여 풀면 될 것이다.
#
# 이 경우 저 두 점을 지나는 정확한 함수가 정해져 있기 때문에 $a$와 $b$, $c$도 단 한 가지 값으로 정해진다.
#
# 하지만 우리가 머신러닝, 혹은 딥러닝에서 다루어야 하는 함수는 정확히 단 하나로 정해져있는 함수도 아닐뿐더러, 그 함수가 이차 함수인지, 삼차 함수인지, 혹은 신경망 형태로 나타날지조차 알지 못한다. 우리에게 주어진 것이라곤 단 하나! **데이터** 뿐이다.
#
# (여기서 잠깐, 신경망이라는 함수는 일차 함수일까, 이차 함수일까, 아니면 어떤 형태의 함수일까? 이 물음에 대한 답은 바로 다음에 다룬다. 그 전에 한번 생각해보자.)
#
# 집 값을 맞추는 문제를 풀 때 우리에게는 집의 평수, 위도와 경도, 층수 등 각 집의 특징을 나타내는 데이터가 있을 것이다. 이러한 특징 데이터를 함수(모델)에 입력했을 때 우리는 모델이 집의 가격을 정확히 맞추기를 바란다. 하지만 현실 세계에서 집의 가격은 아주 복잡한 요인들이 관여한다 (아마 현 시기의 경제 상황이라던가, 그런 설명하기 복잡한 것들까지 반영되었을 것이다!). 그런 모든 요인을 정량화하여 함수에 넣어줄 수 없다면 우리는 완벽한 함수는 만들어낼 수 없을 것이다.
#
# 그렇기에 머신러닝과 딥러닝은 '완벽한 함수'를 찾는 수학 문제를 푸는 것이 아니라, '그나마 가장 잘 근사할 수 있는 함수'에 조금씩 가까워지도록 시도하는 것에 가깝다.
#
# <img src="./image/model.jpg" />

# %% [markdown]
# ### 그나마 나은 함수를 찾기 위해
# ---
# 정리해 보겠다. 우리가 '그나마 가장 잘 근사할 수 있는 함수'를 찾기 위해 해야 할 일은 두 가지이다.

# %% [markdown]
# #### **1. 먼저, 모델을 어떤 함수로 나타낼 것인지를 정해야 합니다.**
#
# * 입력 데이터가 하나인 경우, 즉 One-to-One 문제의 경우에는 f(x)=wx+b와 같은 일차 함수를 사용할 수 있다.
# * 입력 데이터가 여러 개의 특징으로 이루어진 벡터인 경우, 즉 Many-to-One 문제의 경우에는 `f(x) = wx_1 + wx_2 + ... + wx_n` 과 같은 다변수 선형 함수로 정할 수 있다.
# * 물론 신경망 모델을 사용할 수도 있다.
#
# 다양한 모델(함수) 중 어떤 함수를 채택하느냐는 모델의 최종 성능에 굉장히 중요한 영향을 미친다.
#
# 만약 간단한 선형 함수만으로 데이터를 잘 표현할 수 있다고 판단된다면 선형함수를 사용해도 되지만, 이미지나 자연어 같이 형태가 고정되지 않은 '비정형 데이터'같은 경우 최근에는 거의 필연적으로 신경망을 사용한다. 신경망의 구조는 여러 계층이 쌓인 형태이며 이렇게 'Hierarchial(계층적인)' 구조가 비정형 데이터의 표현을 단계별로 잘 추출해낼 수 있다는 것이 실험적으로 보여졌기 때문이다.
#
# 이렇게 어떤 데이터에 대한 문제를 풀기 위해 '이러한 형태의 함수가 유리할 것'이라고 판단하고 함수 공간을 정하는 것을 **Inductive Bias**, 혹은 **Prior**를 가정한다고 한다.
#
# **Inductive Bias**란 **데이터를 설명할 수 있는 최적의 함수가 특정한 함수 공간에 존재할 것이라는 가설**을 말한다.
#
# 예를 들어, 우리가 함수 공간을 $f(x) = wx+b$로 일차 함수 형태로 정해놓고 시작한다면 우리는 데이터를 더 잘 표현할 수 있는 $f(x) = x^2 + 5x + 2$와 같은 이차함수는 영영 못 찾게 될 것이다. 혹은, 이미지나 자연어와 같은 데이터를 처리할 때에 신경망의 형태로 모델을 정해놓고 시작하는 것은 신경망이 비정형 데이터를 표현하는 데에 강력하다는 실험적 결과에 따른 가설에 입각하는 것이다.
#
# 이러한 Inductive Bias가 중요한 이유는 우리가 학습시킬 모델이 세상의 모든 데이터를 볼 수 없기 때문이다. 모델이 학습하는 과정에서 보지 못한 데이터에 대해서도 예측을 잘 하려면(즉, 일반화(Generalization)가 잘 되려면), 일반적인 패턴을 잘 반영할 수 있는 형태의 모델이어야 한다. 그렇기에 어떤 문제를 풀고자 할 때 알맞은 함수 형태로 모델을 선택하는 것은 그 데이터에 대한 도메인 지식을 가지고 있는 사람의 몫이며, 더 좋은 모델을 찾기 위해서는 그 데이터에 알맞은 함수 공간, 즉 Inductive Bias를 잘 설정하는 것이 중요하다.

# %% [markdown]
# #### 2. 모델의 함수 형태를 정했다면, 해당 함수 공간 안에서 최적의 함수를 찾아나갑니다.
#
# 모델을 어떤 함수 형태로 사용할 것인지 정했다면, 그 후로는 그 함수 공간 안에서 찾을 수 있는 최적의 함수로 학습을 해 나간다.
#
# 이 단계가 보통 머신러닝/딥러닝에서 말하는 '모델 학습'에 해당한다.<br>
# 머신러닝 모델을 '학습'시킨다는 것은, 처음에는 데이터를 입력받아 전혀 엉뚱한 값을 내뱉던 모델을, 점점 정답에 해당하는 값을 출력할 수 있도록 '보정'해나가는 과정이라고도 할 수 있다.
#
# 모델을 학습시키는 방법은 모델 형태에 따라 다양하다. 딥러닝의 신경망 모델은 'Gradient Descent(경사하강법)'이라는 방법을 사용한다.
#
# __데이터를 잘 표현/예측할 수 있는 모델(함수)를 찾아내기 위한 두 가지 단계__
#
# - 첫 번째는, 모델을 어떤 함수 형태로 나타낼 것인지 함수 공간을 정하는 단계이다. 선형 함수를 쓸지, 의사결정 나무(Decision Tree) 모델을 쓸지, 혹은 신경망 모델을 쓸지 정해야 하며, 이 과정에서 Inductive Bias가 발생한다.
# - 두 번째, 함수 공간을 정했다면 그 안에서 최적의 함수를 찾아 학습한다. 신경망의 경우 경사하강법과 같은 방법으로 점차 최적의 함수로 학습될 수 있다.
#
# __Inductive Bias란__
#
# - Inductive Bias란, 데이터를 설명할 수 있는 최적의 함수가 특정한 함수 공간에 존재할 것이라는 가설을 말한다.
# - 모든 데이터는 그 데이터가 무엇이냐에 따라 데이터를 잘 표현/예측할 수 있는 함수의 형태가 다르다. 어떤 데이터는 간단한 선형 함수만으로도, 어떤 데이터는 아주 복잡한 신경망으로 나타내야만 표현이 가능할 수도 있다. 데이터에 대한 도메인 지식을 활용하면 데이터를 가장 잘 표현할 수 있는 함수는 어떤 형태일 것이라는 가설을 세울 수 있다. 더 좋은 모델을 만들기 위해서는 좋은 Inductive Bias가 필요하다.

# %% [markdown]
# ## 12. AI의 현재와 미래 (1) 머신러닝과 딥러닝
#
# ***현시대 AI: 어디까지 왔나, 그리고 어디를 향해 가는가***
#
# 지금까지 딥러닝과 신경망에 담긴 철학과 그 본질에 대해 조금이나마 파헤쳐 보았다.
#
# 알아본 철학에 기반하였을 때, 머신러닝과 딥러닝이 어떤 차이를 가지는지, 그리고 두 가지가 추구하는 것이 어떻게 다르다고 설명할 수 있을까?
#
# 머신러닝은 주어진 데이터로부터 패턴을 학습해서 원하는 값을 예측하는 것에 방점이 있다면, 딥러닝은 입력된 데이터에 내재되어 있는 표현 그 자체를 나타내도록 학습하는 것이 목표이다. 다음 이미지로 그 차이가 명확하게 드러난다.
#
# <img src="./image/deep.jpg" />
#
# [https://bigdatapath.wordpress.com/2019/09/13/ai-vs-machine-learning-vs-deep-learning-whats-the-difference/](https://bigdatapath.wordpress.com/2019/09/13/ai-vs-machine-learning-vs-deep-learning-whats-the-difference/)
#
# 기존의 머신러닝은 데이터를 입력하기 위해 사람이 직접 피처(Feature)를 가공해 주어야 했다. 전통적인 머신러닝 모델들은 주로 '표' 형태로 된 정형 데이터를 처리하도록 설계되었기 때문이다. 그래서 지금까지 이미 해봤거나 앞으로도 그럴 예정이듯, 머신러닝 모델을 학습시킬 때에는 데이터를 전처리하고 모델에 들어가도록 이쁘게 가공하는 작업이 필수적이다. 또한, 주어진 데이터를 이리저리 조합해서 더욱 좋은 피처를 만들어내는 것도 성능을 높이기 위한 굉장히 중요한 과정이다. 이러한 과정을 통틀어 피처 엔지니어링(Feature Engineering) 이라고 한다. 피처 엔지니어링은 그 자체로 머신러닝 내에서 한 챕터를 차지할만큼 중요하고 방대한 내용이 많은 분야이다. 그만큼 머신러닝은 더 좋은 모델을 만들기 위해 '사람의 개입'을 굉장히 많이 필요로 한다.
#
# 한편, 딥러닝은 모델의 복잡성을 늘려 사람이 개입하는 피처 엔지니어링을 최소화하고자 한다. 이미지라면 픽셀 형태로 된 2차원 배열을 그대로 신경망에 입력하면, 알아서 그 안에 있는 특징이나 표현을 학습하도록 하자. 물론 자연어라면 한글이나 알파벳을 넣을 순 없기에 자연어를 숫자로 이루어진 벡터 형태로 가공하는 작업은 해야 하지만(자연어 임베딩(Embedding)) 그럼에도 머신러닝과는 조금 다르다. 머신러닝으로는 자연어를 입력받아 기계 번역을 한다던가, 문장을 생성하는 등의 태스크를 수행할 수 없죠. 이처럼 딥러닝은 뚜렷한 형태가 없는(비정형) 데이터로부터 표현을 추출해내는 것에 매우 강한다.
#
# 딥러닝에서는 이렇게 데이터를 모델에 입력해서 바로 원하는 출력값을 얻어내는 End-to-End Learning을 추구하는 경우가 많다. 끝에서 끝까지 모두 담당한다는 정도의 의미가 된다.
#
# 더 다양한 글을 읽어보는 것은 언제나 도움이 된다. 다음 글들을 모두 읽고 다시 한 번 사고를 확장해보자. 아래 글들은 딥러닝과 머신러닝의 패러다임과 그 세부 내용들에 대해 굉장히 잘 설명하고 있으니, 자세히 읽어보길 추천한다.

# %% [markdown]
# ### **1번 글: [머신러닝이란 무엇인가?](https://www.stechstar.com/user/zbxe/index.php?mid=study_SQL&page=14&document_srl=63467)**
#
# ---
#
# __글에서 설명하는 아이의 학습 과정__
#
# - 사물을 보고 그것이 뭔지 알아가는 과정에서 ‘나무’의 다양한 예시들을 더 많이 접하게 되며, 머릿속에서는 맨 처음 봤던 나무의 예시인 ‘갈색의 딱딱하고… 매달려 있는 대상’만이 존재하였던 상태에서, 나무의 예시들을 확장적으로 받아들이면서 동시에 ‘나무’라는 대상의 핵심이 되는 특질을 서서히 압축해 나간다.
# - 즉, 나무의 핵심 특질이 압축된 결과물이 여러분의 머릿속에서 추상적인 형태로 자리잡아 나가며 데이터에 기반한 학습을 행한다.
#
# __선형모델__
#
# * 직선(또는 평면, 초평면 등)의 형태로 정의되는 러닝 모델을 특별히 선형 모델(linear model)이라고 부르며, 이는 가장 단순한 러닝 모델에 해당한다.
#
# __오늘날 이미지 인식 분야에서 선형모델을 쓰지 않는 이유는 무엇이며, 그에 대한 대안으로 떠오른 것은 무엇인가?__
#
# - 선형 모델은 가장 단순하고 (선형 모델로 학습이 가능한 데이터 집합에 한해서) 학습 속도가 빠르며 인간이 이해하기 쉬운 대신, 원 데이터 자체가 수많은 픽셀로 이루어져 있는 이미지와 같은 데이터의 경우에는 데이터의 복잡성을 선형 모델에 충분히 반영하는 것이 불가능하다.
# - 그래서, 실제 이미지 인식 분야에서는 선형 모델 대신 인공신경망(artificial neural networks)과 같은 복잡성이 높은 러닝 모델을 사용한다. 이렇게 복잡성이 높은 신경망(neural networks) 구조를 러닝 모델로 사용하는 머신러닝 패러다임을 ‘딥러닝(deep learning)‘이라고 한다.

# %% [markdown]
# ### **2번 글: [딥러닝이란 무엇인가? (1)](https://www.stechstar.com/user/zbxe/index.php?mid=study_SQL&page=13&document_srl=63482)**
# ---
#
# __퍼셉트론이란__
#
# - 입력 벡터 x=(x_1,x_2,...,x_d)를 받아들인 뒤 각 성분에 가중치를 곱하는 선형 모델을 거쳐, 그 결과를 모두 합산한 후 활성화함수 σ(⋅)을 적용한 함수로 이루어진 모델이다. 전체 과정을 수행하는 이 선형 모델을 하나의 함수 h(⋅)로 나타낼 수 있으며, 이를 퍼셉트론(perceptron)이라고 부른다.
# - 즉, 퍼셉트론은 선형 함수와 그 결과를 비선형 함수 활성화 함수까지 거치는 합성 함수라고 할 수 있다.
#
# __다층 퍼셉트론이란__
#
# - 퍼셉트론은 세 개의 층으로 이루어진다. 입력 벡터가 자리잡는 층을 입력층(input layer), 최종 출력값이 자리잡는 층을 출력층(output layer), 입력층과 출력층 사이에 위치하는 모든 층을 은닉층(hidden layer)이라고 한다.
# - 이 때 퍼셉트론을 기본 빌딩 블록으로 하여, 이런 패턴에 따라 2차원적으로 연결되어 구성되는 인공신경망의 일종을 특별히 다층 퍼셉트론(MLP: multi-layer perceptron)이라고 한다.
#
# __심층 신경망이란__
#
# - 다층 퍼셉트론에서 은닉층의 개수가 많아질수록 인공신경망이 ‘깊어졌다(deep)’고 부르며, 이렇게 충분히 깊어진 인공신경망을 러닝 모델로 사용하는 머신러닝 패러다임을 바로 딥러닝(Deep Learning)이라고 한다.
# - 이 때 딥러닝을 위해 사용하는 충분히 깊은 인공신경망을 심층 신경망(DNN: Deep neural network)이라고 한다.
#
# __글에서 설명하는 대표적인 딥러닝 모델 세 가지는 무엇인가? 각 모델은 어떤 문제에 많이 쓰이는가?__
#
# - 완전 연결 신경망, 컨볼루션 신경망, 순환 신경망이다.
# - 컨볼루션 신경망은 주로 이미지 처리에, 순환 신경망은 주로 자연어 처리에 사용된다.

# %% [markdown]
# ### **3번 글: [딥러닝이란 무엇인가? (2)](https://www.stechstar.com/user/zbxe/index.php?mid=study_SQL&page=13&document_srl=63499)**
#
# ----
#
# __딥러닝의 강점__
#
# * 딥러닝은 ‘요인 표현 학습(feature representation learning)’ 능력을 가지고 있으며, 이는 원본 데이터로부터 최적의 성능을 발휘하는 데 사용될 수 있는 요인 표현 방법을 스스로 학습하고, 이를 기반으로 최적의 성능을 발휘하는 가중치를 더욱 효과적으로 찾는 능력을 말한다.
#
# __컨볼루션 신경망의 낮은 층(입력에 가까운 층)에서는 어떤 특징을, 높은 층(출력에 가까운 층)에서는 어떤 특징을 추출하는가?__
#
# - 컨볼루션 신경망의 낮은 층에 해당할수록, 이미지 상의 각 세부 영역에서의 경계, 명암, 색상 변화 등 저수준(low-level)의 특징들을 요인 표현으로 포착하는 경향을 보인다. 이렇게 위치 별 저수준 요인은, 컨볼루션 신경망의 높은 층으로 올라가면서 서로 가까운 것들끼리 조합되고, 좀 더 넓은 영역에서 고수준(high-level)의 특징들을 요인 표현으로 포착하는 경향을 보인다.
# - 이렇게 낮은 층에서는 점, 선, 면과 같은 간단한 요인들을 추출하고, 점점 높은 층에 다다를수록 복잡한 요인들을 추출하며 최종적으로 이미지를 인식해나간다.
#
# __딥러닝의 약점__
#
# * 딥러닝 모델이 효과적으로 학습하기 위해서는 굉장히 많은 데이터가 필요하며, 학습 연산량이 매우 높아 학습 시간이 낮다는 것이 약점이다.

# %% [markdown]
# ## 13. AI의 현재와 미래 (2) 딥러닝은 블랙박스인가 아닌가, 끝나지 않는 논쟁

# %% [markdown]
# ### 딥러닝 모델은 블랙박스인가?
# ---
# 그렇다면 그 다음으로 고민해 보아야 할 것은 바로 '딥러닝은 블랙박스인가 아닌가?'에 대한 논쟁이다.
#
# "블랙박스"라는 용어는 안에서 어떤 일이 일어나고 있는지 알지 못한다는 의미를 담고 있다.<br>
# 2020년 6월 초에 나온 GPT-3는 무려 1,750억개의 변수로 이루어져있다고 한다. 1,750억개의 숫자들이 학습되어 그 내부에서 엄청나게 복잡하게 연산을 하고 있다고 하니, 그 안에서 어떤 일이 벌어지는지 전부 다 안다고 할 수 없을 만도 하다.<br>
# 하지만 신경망이라는 모델이 블랙박스인지 아닌지는 계속해서 논쟁이 되고 있다. 다음 글들을 읽고 고민해보자.

# %% [markdown]
# #### **'동작하는 원리를 알고 있으니 블랙박스가 아니다' 라는 주장**
#
# * **[블랙박스(Black box)라고?](https://blog.pabii.co.kr/aint-blackbox/)**
#
# __딥러닝이 블랙박스가 아니라고 주장하는 이유는 무엇인가?__
#
# - 신경망은 여러 개의 함수를 엮어 놓은 것이라고 할 수 있고, 그 함수는 본질적으로 회귀 식과 형태가 같다.
# - 즉, 여러 함수의 연산은 간단한 계산으로 이루어져 있고, 그 함수들이 합성된 형태로 수가 어떻게 연산되는지, 어떤 원리로 동작하는지 알기 때문에 블랙박스라고 할 수 없다.

# %% [markdown]
# #### **'왜 그런 결과를 내놓았는지 설명하지 못하므로 블랙박스다' 라는 주장**
#
# * **[못 믿겠다 AI, 설계자도 심층신경망 작동 방식 몰라](https://news.joins.com/article/22394025)**
#
# __기사에서는 왜 딥러닝이 블랙박스라고 이야기하는가?__
#
# - 딥러닝의 구조는 매우 복잡하고 그 연산량 또한 엄청나게 많기 때문에 그 계산 과정을 전체적으로 이해하는 것은 불가능하다.
# - 학습된 딥러닝 모델이 어떤 결과를 내놓을지 예측할 수 없으며, 모델이 내놓은 결과가 어떤 판단 근거에 따라 판단되었는지 또한 설명할 수 없다.
# - 예를 들어 어느 은행의 인공지능 프로그램이 컴퓨터가 당신의 대출을 거부한 경우, 어떤 근거로 거부 결정을 내렸는지는 실제로 프로그램을 만든 사람조차도 알 수 없다. 이러한 성질로 인해 딥러닝은 블랙박스라고 할 수 있다.

# %% [markdown]
# 어떤가? 신경망이 동작하는 원리를 알고 있으니 블랙박스라고 할 수 없다는 주장과, 모델이 특정 결과를 내놓았을 때 어떤 점에 기인하여 그 결과를 내었는지 설명할 수 없으므로 블랙박스라고 이야기하는 설명이 있었다.
#
# 두 주장 모두 일리가 있다. 하지만 보통 비즈니스에 딥러닝 기술을 접목하는 경우에는 모델이 만들어 낸 결과가 '왜 그렇게 나왔는지'를 설명할 수 있어야 하는 경우가 많다. 인공지능이 만들어내는 결과를 믿기 위해 이루어지는 이러한 연구를 Interpretable Machine Learning, 혹은 Explainable AI (XAI, 설명 가능한 인공지능) 라고 한다.
#
# * **[설명가능 인공지능이란?](https://realblack0.github.io/2020/04/27/explainable-ai.html)**
#
# __머신러닝 모델에 대해 해석을 할 수 있어야 하는 이유는 무엇인가? 혹은 그로 인한 이점은 무엇인가?__
#
# - 모델이 예측한 결과가 어떠한 과정으로 도출되었는지 설명할 수 있다면 납득할 만한 과정을 거쳐 도출되었다는 것을 확인함으로써 그 결과를 신뢰할 수 있다.
# - 상용화 및 대중화를 염두에 두고 머신러닝 기술이 핵심이 되는 제품을 출시하고자 할수록, 제품 사용자가 제품을 신뢰하기 위한 설명의 중요성은 더 높아진다.
#
# 이렇게 머신러닝/딥러닝 모델은 예측하거나 출력한 결과가 어떻게 도출되었는지 설명할 수 있어야 신뢰도를 높일 수 있다.

# %% [markdown]
# ### LIME 라이브러리
# ---
# Interpretable Machine Learning을 할 수 있도록 도와주는 라이브러리 중 하나인 LIME을 알아보겠다.
#
# [![Lime](http://img.youtube.com/vi/hUnRCxnydCc/0.jpg)](https://youtu.be/hUnRCxnydCc?t=0s)
#
# __LIME의 핵심 아이디어__
#
# - LIME의 핵심 아이디어는 '입력값을 조금 바꿨을 때 모델의 예측값이 크게 바뀌면, 그 변수는 중요한 변수이다.'라는 것이다.
# - 즉, 이미지의 경우 이미지를 잘게 쪼개어 각 부분을 지운 상태로 넣었을 때 출력값이 크게 바뀌는지 아닌지를 확인하여 어떤 부분이 모델이 예측을 만들어 내는 데에 중요하게 작용했는지를 찾아낸다.

# %% [markdown]
# ## 14. AI의 현재와 미래 (3) 현시대 AI
#
# ***어디까지 왔나, 그리고 어디를 향해 가는가***
#
# 자, 이제 정말 막바지에 다다랐다.
#
# 오늘 과정은 현재 AI가 어디까지 왔는지, 그리고 앞으로 해결하고자 하는 문제는 무엇인지에 대해 알아보고 마무리 할 예정이다.
#
# 먼저, 현재 글을 작성하고 있는 시점에서 가장 최근인 2020년 6월 초에 OpenAI에서 발표한 최신 모델 GPT-3은 놀랄만한 결과물을 보여준다.
#
# 아래 이미지들은 OpenAI가 GPT-3를 API 형태로 쓸 수 있는 데모를 보여준 예시이다.
#
# <img src="./image/gpt.jpg" />
#
# [https://openai.com/blog/openai-api/](https://openai.com/blog/openai-api/)
#
# GPT-3 API를 사용하면 위키피디아의 'Bread' 페이지에서 'why is bread so fluffy?'라는 질문을 검색했을 경우 마치 구글에서 검색을 하듯 그 질문의 답이 들어있는 문단을 바로 찾아준다. 질문의 의도와 문맥을 이해하고, 페이지 내에 있는 내용 또한 이해해서 질문에 맞는 부분을 찾아주는것이다.
#
# 거의 사람에게 물어봤을 때 해당 부분을 찾아주는 것과 비슷한 태스크라고도 할 수 있을 정도이다.
#
# <img src="./image/shell.jpg" />
#
# [https://openai.com/blog/openai-api/](https://openai.com/blog/openai-api/)
#
# 이번에는 리눅스 쉘의 코드를 입력해 주는 시나리오이다. 사람이 코드를 직접 짜는 대신, 그냥 자연어로 질문한다. 'what day is it?' 하면, 리눅스에서 오늘 날짜를 출력해주는 명령어인 **`date +%A`** 라는 명령어를 생성해낸다. 더 재미있는 건, 오타를 내기도 한다. 요일과 날짜를 함께 출력하기 위해서는 **`date +%A %F`**가 아니라 **`date '+%A %F'`**와 같이 따옴표를 입력해야 하는데, 이렇게 오타가 나서 사람이 'I think you forgot the quotes'라고 알려주자 따옴표(quote)를 올바르게 입력한 명령어를 다시 잘 만들어낸다.
#
# 이 정도면 사람이 직접 코딩을 할 필요 없이 쉘과 정말 '대화'를 하면서 코드를 짤 수도 있을 것 같다. 저희는 이제 프로그래밍 언어를 배우지 않아도 프로그래밍을 할 수 있게 되는 걸까?
#
# 한 가지 더 신기한 것은 아래 그림이다. 위의 GPT-3 모델을 그대로 활용해서 이미지를 생성한 결과이다.
#
# <img src="./image/gpt3.jpg" />
#
# [https://openai.com/blog/image-gpt/](https://openai.com/blog/image-gpt/)
#
# 맨 오른쪽 열에는 원본 이미지가, 맨 왼쪽 열에는 반이 잘린 원본 이미지가 있다. 두 번째부터 다섯 번째 열은 GPT-3 모델이 맨 왼쪽 열의 이미지를 입력받아 생성한 이미지이다.
#
# 어떤가? 물의 파장도, 바둑알도, 사람의 그림자도.. 모두 경이롭기까지 하다.
#
# 더욱 놀라운 것은 자연어를 생성하기 위해 만들어진 GPT-3 모델이 같은 구조로 이미지도 생성해낼 수 있다는 것이다. 인공지능 연구자들의 오랜 꿈인 '강인공지능', 혹은 'Generalized AI'가 머지 않았다고 느껴질 정도이다.
#
# 마지막으로 한 가지 글을 소개하고 마치도록 하겠다. <br>
# 강화학습 분야의 대가인 리처드 서튼이 2019년 5월 작성한 *The Bitter Lesson*이라는 글인데, 번역이 된 글이 있어서 소개한다.
#
# * [The Bitter Lesson 번역](https://newsight.tistory.com/302)
#
# 글의 요지는 '사람이 자신의 지능과 경험을 인공지능에 담으려고 노력하는 것보다, 하드웨어와 연산 속도를 높이는 것이 훨씬 더 큰 도약을 만들어냈다'는 씁쓸한 교훈이다.
#
# 2020년의 중턱에 있는 지금, 하루가 멀다하고 새로운 모델, 엄청난 기술들이 쏟아져 나오고 있다. 사실 위에서 본 GPT-3도 1,750억 개에 달하는 파라미터를 가지고 있다. 알고리즘을 발전시키는 연구도 중요하지만, 현재로서는 더욱 많은 연산을 가능케 하기 위해 하드웨어를 더 효율적으로 사용하는 것도 매우 중요하다.
