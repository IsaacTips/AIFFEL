# %% [markdown]
# # 8. 도로 영역을 찾자! - 세그멘테이션 모델 만들기

# %% [markdown]
# ## 5. 프로젝트 : 개선된 U-Net 모델 만들기
# U-Net을 통한 시맨틱 세그멘테이션 결과가 만족스럽게 나왔을까? 어느정도 동작하는 것 같긴 하지만 좀 더 개선할 여지도 보일 것이다.
#
# 2018년에 U-Net++라는 논문이 나왔다. 이 논문은 기존에 아주 단순하면서도 세그멘테이션에서 효과를 발휘했던 U-Net의 네트워크 구조에 DenseNet의 아이디어를 가미하여 성능을 개선한 모델이다.
#
# 그래서 모델의 구조 자체는 아래 그림에서 보는 것처럼 별다른 설명이 없이도 직관적으로 이해가 가능한 수준이다. 오늘 소개되었던 U-Net의 모델 코드를 조금만 수정 확장하면 충분히 구현할 수 있을 것이다. 그래서 오늘의 과제는 바로 U-Net++ 모델을 스스로의 힘으로 직접 구현해 보고, U-Net을 활용했던 도로 세그멘테이션 태스크에 적용하여 U-Net을 썼을 때보다 성능이 향상되었음을 확인해 보는 것이다. 정성적으로는 두 모델의 세그멘테이션 결과를 시각화해서 비교해 볼 수 있을 것이고, 정량적으로는 동일 이미지에 대한 IoU값을 비교해 보면 될 것이다.
#
# * (참고) [U-Net++ 저자 블로그](https://sh-tsang.medium.com/review-unet-a-nested-u-net-architecture-biomedical-image-segmentation-57be56859b20)
#
# <img src="./image/UNPP.png" />

# %% [markdown]
# ## 시맨틱 세그멘테이션 데이터셋

# %% [markdown]
# ### 이미지, 데이터 가져오기
# ---
# 먼저 __시맨틱 세그멘테이션(semantic segmentation)__으로 도로의 영역을 분리하기 위해서는 도로의 영역을 라벨로 가진 데이터셋을 가지고 학습할 수 있도록 파싱해야 한다. 아래 링크를 통해서 물체 검출(object detection)으로 사용했던 __KITTI 데이터셋의 세그멘테이션 데이터__를 다운로드 한다.
#
# 데이터 출처: http://www.cvlibs.net/datasets/kitti/eval_semantics.php
#
# ```bash
# $ mkdir -p ~/AIFFEL/Going_Deeper/GD8_Segmentation2/semantic_segmentation/data
# $ wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_semantics.zip
# $ unzip data_semantics.zip -d ~/AIFFEL/Going_Deeper/GD8_Segmentation2/semantic_segmentation/data
# ```
#
# 아래는 데이터셋에서 확인할 수있는 이미지와 라벨이다. 지금까지 보던 라벨 데이터와 다르게 세그멘테이션 데이터는 이미지 형태의 라벨으로 되어있다.
#
# <img src="./image/KITTI.png" />
# <center><b>[KITTI 데이터셋]</b></center>
#
# <img src="./image/KITTI_seg.png" />
# <center><b>[KITTI 데이터셋 segmentation]</b></center>
#
# <img src="./image/KITTI_seg_rgb.png" />
# <center><b>[KITTI 데이터셋 segmentation_rgb]</b></center>

# %% [markdown]
# ### 데이터 로더(data loader) 만들기
# ---
# 이제 이미지와 데이터셋이 주어졌으니 모델을 학습시킬 수 있는 데이터 로더(data loader)를 만들어보자. 로더는 입력값 `(224, 224)`, 출력값 `(224, 244)` 크기를 갖는 모델을 학습시킬 수 있도록 데이터셋을 파싱해야 한다.
#
# 이때 데이터 로더에 __augmentation__을 적용해보자. 오늘은 파이썬에서 많이 사용되는 `albumentations`을 사용해 보겠다. 하지만 Augmentation의 경우 `imgaug` 등 다른 라이브러리를 활용해도 된다.
#
# ```bash
# $ pip install albumentations
# ```
#
# 또한 학습셋의 일정량을 __검증 데이터셋(validation dataset)__으로 활용할 수 있도록 해야 한다.
#
# 구현을 할 때는 아래 자료를 참고해보자.
#
# * [Keras Sequence에 기반한 Dataloader](https://hwiyong.tistory.com/241)
# * [Albumentation을 적용한 Keras sequence](https://medium.com/the-artificial-impostor/custom-image-augmentation-with-keras-70595b01aeac)
#
# 만든 후에는 직접 데이터셋이 잘 파싱되어 나오는지 꼭 확인해보자. 데이터셋에 오류가 없어야 성능이 안 나오더라도 문제를 찾아내기 쉽다.

# %%
#필요한 라이브러리를 로드합니다. 
import os
import math
import numpy as np
import tensorflow as tf

from PIL import Image
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize
from glob import glob

from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *

# %% [markdown]
# Albumentation 의 사용법을 간단히 알아보겠다. 아래는 Albumentation에서 다양한 augmentation 기법을 확률적으로 적용할 수 있게 해주는 `Compose()`의 활용예이다. imgaug의 `Sometimes()`와 유사한 기능이다.

# %%
from albumentations import  HorizontalFlip, RandomSizedCrop, Compose, OneOf, Resize

def build_augmentation(is_train=True):
    if is_train:    # 훈련용 데이터일 경우
        return Compose([
                        HorizontalFlip(p=0.5),    # 50%의 확률로 좌우대칭
                        RandomSizedCrop(         # 50%의 확률로 RandomSizedCrop
                            min_max_height=(300, 370),
                            w2h_ratio=370/1242,
                            height=224,
                            width=224,
                            p=0.5
                            ),
                        Resize(              # 입력이미지를 224X224로 resize
                            width=224,
                            height=224
                            )
                        ])
    return Compose([      # 테스트용 데이터일 경우에는 224X224로 resize만 수행합니다. 
                  Resize(
                      width=224,
                      height=224
                      )
                  ])

# %%
import os

dir_path = os.getenv('HOME')+'/AIFFEL/Going_Deeper/GD8_Segmentation2/semantic_segmentation/data/training'

augmentation = build_augmentation()
input_images = glob(os.path.join(dir_path, "image_2", "*.png"))

# 훈련 데이터셋에서 5개만 가져와 augmentation을 적용해 봅시다.  
plt.figure(figsize=(12, 20))
for i in range(5):
    image = imread(input_images[i]) 
    image_data = {"image":image}
    resized = augmentation(**image_data, is_train=False)
    processed = augmentation(**image_data)
    plt.subplot(5, 2, 2*i+1)
    plt.imshow(resized["image"])  # 왼쪽이 원본이미지
    plt.subplot(5, 2, 2*i+2)
    plt.imshow(processed["image"])  # 오른쪽이 augment된 이미지
plt.show()

# %% [markdown]
# ### Step 1. KITTI 데이터셋 수집과 구축
# ---
# 다운받아 둔 KITTI 데이터에 data augmentation을 적용한 형태로 데이터셋을 구축한다. 이때 주의할 점이 있다. U-Net++는 내부적인 메모리 사용량이 U-Net보다 꽤 많아진다. 8GB의 GPU 메모리를 가진 모델의 경우 학습데이터의 배치 사이즈를 16->4 로 줄여서 설정하기를 권장한다.

# %% [markdown]
# 이제 데이터셋을 구성해보자. 이번에는 `tf.keras.utils.Sequence`를 상속받은 generator 형태로 데이터를 구성해 보겠다.

# %%
class KittiGenerator(tf.keras.utils.Sequence):
    '''
    KittiGenerator는 tf.keras.utils.Sequence를 상속받습니다.
    우리가 KittiDataset을 원하는 방식으로 preprocess하기 위해서 Sequnce를 커스텀해 사용합니다.
    '''
    def __init__(self, 
                 dir_path,
                 batch_size=2,
                 img_size=(224, 224, 3),
                 output_size=(224, 224),
                 is_train=True,
                 augmentation=None):
        '''
        dir_path: dataset의 directory path입니다.
        batch_size: batch_size입니다.
        img_size: preprocess에 사용할 입력이미지의 크기입니다.
        output_size: ground_truth를 만들어주기 위한 크기입니다.
        is_train: 이 Generator가 학습용인지 테스트용인지 구분합니다.
        augmentation: 적용하길 원하는 augmentation 함수를 인자로 받습니다.
        '''
        self.dir_path = dir_path
        self.batch_size = batch_size
        self.is_train = is_train
        self.dir_path = dir_path
        self.augmentation = augmentation
        self.img_size = img_size
        self.output_size = output_size

        # load_dataset()을 통해서 kitti dataset의 directory path에서 라벨과 이미지를 확인합니다.
        self.data = self.load_dataset()

    def load_dataset(self):
        # kitti dataset에서 필요한 정보(이미지 경로 및 라벨)를 directory에서 확인하고 로드하는 함수입니다.
        # 이때 is_train에 따라 test set을 분리해서 load하도록 해야합니다.
        input_images = glob(os.path.join(self.dir_path, "image_2", "*.png"))
        label_images = glob(os.path.join(self.dir_path, "semantic", "*.png"))
        input_images.sort()
        label_images.sort()
        assert len(input_images) == len(label_images)
        data = [ _ for _ in zip(input_images, label_images)]

        if self.is_train:
            return data[:-30]
        return data[-30:]
    
    def __len__(self):
        # Generator의 length로서 전체 dataset을 batch_size로 나누고 소숫점 첫째자리에서 올림한 값을 반환합니다.
        return math.ceil(len(self.data) / self.batch_size)

    def __getitem__(self, index):
        # 입력과 출력을 만듭니다.
        # 입력은 resize및 augmentation이 적용된 input image이고 
        # 출력은 semantic label입니다.
        batch_data = self.data[
                               index*self.batch_size:
                               (index + 1)*self.batch_size
                               ]
        inputs = np.zeros([self.batch_size, *self.img_size])
        outputs = np.zeros([self.batch_size, *self.output_size])
        
        for i, data in enumerate(batch_data):
            input_img_path, output_path = data
            _input = imread(input_img_path)
            _output = imread(output_path)
            _output = (_output==7).astype(np.uint8)*1
            data = {
                    "image": _input,
                    "mask": _output,
                    }
            augmented = self.augmentation(**data)
            inputs[i] = augmented["image"]/255
            outputs[i] = augmented["mask"]
            return inputs, outputs

    def on_epoch_end(self):
        # 한 epoch가 끝나면 실행되는 함수입니다. 학습중인 경우에 순서를 random shuffle하도록 적용한 것을 볼 수 있습니다.
        self.indexes = np.arange(len(self.data))
        if self.is_train == True :
            np.random.shuffle(self.indexes)
            return self.indexes

# %%
augmentation = build_augmentation()
test_preproc = build_augmentation(is_train=False)
        
train_generator = KittiGenerator(
    dir_path, 
    augmentation=augmentation,
)

test_generator = KittiGenerator(
    dir_path, 
    augmentation=test_preproc,
    is_train=False
)

# %% [markdown]
# ## 시맨틱 세그멘테이션 모델
#
# <img src="./image/model.png" />

# %% [markdown]
# ### 모델 구조 만들기
# ---
# 시맨틱 세그멘테이션을 위한 모델을 만들어보자. 세그멘테이션 모델 중 구조상 비교적 구현이 단순한 `U-Net`을 구현해보자.
#
# 이때 입력 이미지의 크기는 위에서 만든 데이터셋에 맞춰서 만들자.
#
# 사용에 필요한 레이어와 연산은 다음과 같다. 그리고 필요에 따라서 Dropout등의 다른 레이어를 적용해보자.
#
# * `Conv2D`, `UpSampling2D`, `MaxPooling2D`, `concatenate`

# %%
def UNet_build_model(input_shape=(224, 224, 3)):
    inputs = Input(input_shape)

    #Contracting Path
    conv1 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(inputs)
    conv1 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool1)
    conv2 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool2)
    conv3 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool3)
    conv4 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool4)  
    conv5 = Conv2D(1024, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv5)

    #Expanding Path
    drop5 = Dropout(0.5)(conv5)
    up6 = Conv2DTranspose(512, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(drop5)
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv6)
    up7 = Conv2DTranspose(256, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv6)
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv7)
    up8 = Conv2DTranspose(128, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv7)
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv8)
    up9 = Conv2DTranspose(64, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv8)
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv9)  
    conv9 = Conv2D(2, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv9)     
    conv10 = Conv2D(1, 1, activation='sigmoid')(conv9)

    model = Model(inputs = inputs, outputs = conv10)
    return model

# %%
model = UNet_build_model()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 224, 224, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 112, 112, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 112, 112, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 112, 112, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 56, 56, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 56, 56, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 512)  2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 28, 28, 512)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 512)  0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 14, 14, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 14, 14, 1024) 9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 14, 14, 1024) 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 28, 28, 512)  2097664     dropout_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 28, 28, 1024) 0           dropout[0][0]
#                                                                  conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 512)  2359808     conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 56, 56, 256)  524544      conv2d_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 56, 56, 512)  0           conv2d_5[0][0]
#                                                                  conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 56, 56, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 56, 56, 256)  590080      conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 112, 112, 128 131200      conv2d_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 112, 112, 256 0           conv2d_3[0][0]
#                                                                  conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 112, 112, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 112, 112, 128 147584      conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 224, 224, 64) 32832       conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 224, 224, 128 0           conv2d_1[0][0]
#                                                                  conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 224, 224, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 224, 224, 64) 36928       conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 224, 224, 2)  1154        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 224, 224, 1)  3           conv2d_18[0][0]
# ==================================================================================================
# Total params: 31,032,837
# Trainable params: 31,032,837
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### 모델 학습하기
# ---
# 이제 모델을 만들었으니 위에서 만들어본 데이터셋으로 학습 해보자! 적절한 learning rate와 epoch를 찾아서 모델을 학습하고 저장하자.

# %%
model.compile(optimizer = Adam(lr = 1e-4), loss = 'binary_crossentropy')
model.fit_generator(
     generator=train_generator,
     validation_data=test_generator,
     steps_per_epoch=len(train_generator),
     epochs=100,
 )

model_path = dir_path + '/seg_model_unet.h5'
model.save(model_path)  #학습한 모델을 저장해 주세요.
# Out:
# Epoch 1/100
# /home/aiffel-dj10/anaconda3/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# 11/11 [==============================] - 47s 672ms/step - loss: 0.6888 - val_loss: 0.6532
# Epoch 2/100
# 11/11 [==============================] - 7s 630ms/step - loss: 0.5767 - val_loss: 0.0425
# Epoch 3/100
# 11/11 [==============================] - 7s 628ms/step - loss: 0.0313 - val_loss: 0.0381
# Epoch 4/100
# 11/11 [==============================] - 7s 625ms/step - loss: 0.0311 - val_loss: 0.0308
# Epoch 5/100
# 11/11 [==============================] - 7s 629ms/step - loss: 0.0253 - val_loss: 0.0302
# Epoch 6/100
# 11/11 [==============================] - 7s 627ms/step - loss: 0.0249 - val_loss: 0.0349
# Epoch 7/100
# 11/11 [==============================] - 7s 611ms/step - loss: 0.0350 - val_loss: 0.0252
# Epoch 8/100
# 11/11 [==============================] - 7s 628ms/step - loss: 0.0240 - val_loss: 0.1149
# Epoch 9/100
# 11/11 [==============================] - 7s 630ms/step - loss: 0.0281 - val_loss: 0.0254
# Epoch 10/100
# 11/11 [==============================] - 7s 630ms/step - loss: 0.0241 - val_loss: 0.0224
# Epoch 11/100
# 11/11 [==============================] - 7s 628ms/step - loss: 0.0247 - val_loss: 0.0265
# Epoch 12/100
# 11/11 [==============================] - 7s 629ms/step - loss: 0.0226 - val_loss: 0.0202
# Epoch 13/100
# 11/11 [==============================] - 7s 630ms/step - loss: 0.0229 - val_loss: 0.0244
# Epoch 14/100
# 11/11 [==============================] - 7s 633ms/step - loss: 0.0191 - val_loss: 0.0206
# Epoch 15/100
# 11/11 [==============================] - 6s 493ms/step - loss: 0.0144 - val_loss: 0.0212
# Epoch 16/100
# 11/11 [==============================] - 5s 486ms/step - loss: 0.0179 - val_loss: 0.0201
# Epoch 17/100
# 11/11 [==============================] - 5s 483ms/step - loss: 0.0158 - val_loss: 0.0222
# Epoch 18/100
# 11/11 [==============================] - 5s 482ms/step - loss: 0.0185 - val_loss: 0.0202
# Epoch 19/100
# 11/11 [==============================] - 6s 523ms/step - loss: 0.0170 - val_loss: 0.0207
# Epoch 20/100
# 11/11 [==============================] - 6s 518ms/step - loss: 0.0170 - val_loss: 0.0201
# Epoch 21/100
# 11/11 [==============================] - 7s 626ms/step - loss: 0.0142 - val_loss: 0.0222
# Epoch 22/100
# 11/11 [==============================] - 7s 622ms/step - loss: 0.0174 - val_loss: 0.0204
# Epoch 23/100
# 11/11 [==============================] - 6s 564ms/step - loss: 0.0167 - val_loss: 0.0195
# Epoch 24/100
# 11/11 [==============================] - 7s 612ms/step - loss: 0.0152 - val_loss: 0.0203
# Epoch 25/100
# 11/11 [==============================] - 7s 624ms/step - loss: 0.0160 - val_loss: 0.0221
# Epoch 26/100
# 11/11 [==============================] - 7s 622ms/step - loss: 0.0177 - val_loss: 0.0315
# Epoch 27/100
# 11/11 [==============================] - 7s 615ms/step - loss: 0.0157 - val_loss: 0.0210
# Epoch 28/100
# 11/11 [==============================] - 7s 613ms/step - loss: 0.0175 - val_loss: 0.0320
# Epoch 29/100
# 11/11 [==============================] - 7s 624ms/step - loss: 0.0164 - val_loss: 0.0251
# Epoch 30/100
# 11/11 [==============================] - 7s 625ms/step - loss: 0.0261 - val_loss: 0.0227
# Epoch 31/100
# 11/11 [==============================] - 7s 622ms/step - loss: 0.0191 - val_loss: 0.0223
# Epoch 32/100
# 11/11 [==============================] - 7s 620ms/step - loss: 0.0208 - val_loss: 0.0208
# Epoch 33/100
# 11/11 [==============================] - 7s 623ms/step - loss: 0.0199 - val_loss: 0.0222
# Epoch 34/100
# 11/11 [==============================] - 7s 621ms/step - loss: 0.0176 - val_loss: 0.0219
# Epoch 35/100
# 11/11 [==============================] - 7s 621ms/step - loss: 0.0154 - val_loss: 0.0226
# Epoch 36/100
# 11/11 [==============================] - 7s 610ms/step - loss: 0.0203 - val_loss: 0.0210
# Epoch 37/100
# 11/11 [==============================] - 7s 610ms/step - loss: 0.0129 - val_loss: 0.0298
# Epoch 38/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.0193 - val_loss: 0.0222
# Epoch 39/100
# 11/11 [==============================] - 7s 621ms/step - loss: 0.0179 - val_loss: 0.0209
# Epoch 40/100
# 11/11 [==============================] - 7s 624ms/step - loss: 0.0184 - val_loss: 0.0207
# Epoch 41/100
# 11/11 [==============================] - 7s 621ms/step - loss: 0.0150 - val_loss: 0.0204
# Epoch 42/100
# 11/11 [==============================] - 7s 624ms/step - loss: 0.0154 - val_loss: 0.0202
# Epoch 43/100
# 11/11 [==============================] - 7s 626ms/step - loss: 0.0118 - val_loss: 0.0204
# Epoch 44/100
# 11/11 [==============================] - 7s 623ms/step - loss: 0.0159 - val_loss: 0.0206
# Epoch 45/100
# 11/11 [==============================] - 7s 620ms/step - loss: 0.0121 - val_loss: 0.0203
# Epoch 46/100
# 11/11 [==============================] - 7s 622ms/step - loss: 0.0169 - val_loss: 0.0202
# Epoch 47/100
# 11/11 [==============================] - 7s 621ms/step - loss: 0.0126 - val_loss: 0.0205
# Epoch 48/100
# 11/11 [==============================] - 7s 620ms/step - loss: 0.0146 - val_loss: 0.0201
# Epoch 49/100
# 11/11 [==============================] - 7s 619ms/step - loss: 0.0159 - val_loss: 0.0212
# Epoch 50/100
# 11/11 [==============================] - 7s 615ms/step - loss: 0.0162 - val_loss: 0.0219
# Epoch 51/100
# 11/11 [==============================] - 7s 609ms/step - loss: 0.0152 - val_loss: 0.0212
# Epoch 52/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.0170 - val_loss: 0.0206
# Epoch 53/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.0144 - val_loss: 0.0219
# Epoch 54/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.0170 - val_loss: 0.0212
# Epoch 55/100
# 11/11 [==============================] - 7s 609ms/step - loss: 0.0147 - val_loss: 0.0206
# Epoch 56/100
# 11/11 [==============================] - 7s 626ms/step - loss: 0.0148 - val_loss: 0.0207
# Epoch 57/100
# 11/11 [==============================] - 7s 624ms/step - loss: 0.0183 - val_loss: 0.0231
# Epoch 58/100
# 11/11 [==============================] - 7s 625ms/step - loss: 0.0161 - val_loss: 0.0313
# Epoch 59/100
# 11/11 [==============================] - 7s 624ms/step - loss: 0.0223 - val_loss: 0.0216
# Epoch 60/100
# 11/11 [==============================] - 7s 626ms/step - loss: 0.0154 - val_loss: 0.0245
# Epoch 61/100
# 11/11 [==============================] - 7s 627ms/step - loss: 0.0149 - val_loss: 0.0210
# Epoch 62/100
# 11/11 [==============================] - 7s 621ms/step - loss: 0.0145 - val_loss: 0.0209
# Epoch 63/100
# 11/11 [==============================] - 7s 618ms/step - loss: 0.0154 - val_loss: 0.0213
# Epoch 64/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.0150 - val_loss: 0.0214
# Epoch 65/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.0151 - val_loss: 0.0235
# Epoch 66/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.0157 - val_loss: 0.0210
# Epoch 67/100
# 11/11 [==============================] - 7s 611ms/step - loss: 0.0157 - val_loss: 0.0219
# Epoch 68/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.0202 - val_loss: 0.0207
# Epoch 69/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.0151 - val_loss: 0.0209
# Epoch 70/100
# 11/11 [==============================] - 7s 603ms/step - loss: 0.0139 - val_loss: 0.0208
# Epoch 71/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.0139 - val_loss: 0.0211
# Epoch 72/100
# 11/11 [==============================] - 7s 604ms/step - loss: 0.0143 - val_loss: 0.0213
# Epoch 73/100
# 11/11 [==============================] - 7s 604ms/step - loss: 0.0149 - val_loss: 0.0221
# Epoch 74/100
# 11/11 [==============================] - 7s 615ms/step - loss: 0.0135 - val_loss: 0.0203
# Epoch 75/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.0145 - val_loss: 0.0224
# Epoch 76/100
# 11/11 [==============================] - 7s 608ms/step - loss: 0.0183 - val_loss: 0.0205
# Epoch 77/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.0105 - val_loss: 0.0211
# Epoch 78/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.0125 - val_loss: 0.0210
# Epoch 79/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.0147 - val_loss: 0.0217
# Epoch 80/100
# 11/11 [==============================] - 7s 604ms/step - loss: 0.0168 - val_loss: 0.0233
# Epoch 81/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.0171 - val_loss: 0.0214
# Epoch 82/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.0166 - val_loss: 0.0208
# Epoch 83/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.0186 - val_loss: 0.0205
# Epoch 84/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.0139 - val_loss: 0.0215
# Epoch 85/100
# 11/11 [==============================] - 7s 604ms/step - loss: 0.0175 - val_loss: 0.0213
# Epoch 86/100
# 11/11 [==============================] - 7s 606ms/step - loss: 0.0173 - val_loss: 0.0207
# Epoch 87/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.0138 - val_loss: 0.0216
# Epoch 88/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.0159 - val_loss: 0.0208
# Epoch 89/100
# 11/11 [==============================] - 7s 605ms/step - loss: 0.0156 - val_loss: 0.0219
# Epoch 90/100
# 11/11 [==============================] - 7s 607ms/step - loss: 0.0131 - val_loss: 0.0203
# Epoch 91/100
# 11/11 [==============================] - 7s 618ms/step - loss: 0.0177 - val_loss: 0.0238
# Epoch 92/100
# 11/11 [==============================] - 7s 623ms/step - loss: 0.0175 - val_loss: 0.0205
# Epoch 93/100
# 11/11 [==============================] - 7s 623ms/step - loss: 0.0159 - val_loss: 0.0205
# Epoch 94/100
# 11/11 [==============================] - 7s 624ms/step - loss: 0.0124 - val_loss: 0.0206
# Epoch 95/100
# 11/11 [==============================] - 7s 623ms/step - loss: 0.0145 - val_loss: 0.0213
# Epoch 96/100
# 11/11 [==============================] - 7s 622ms/step - loss: 0.0115 - val_loss: 0.0208
# Epoch 97/100
# 11/11 [==============================] - 7s 624ms/step - loss: 0.0132 - val_loss: 0.0206
# Epoch 98/100
# 11/11 [==============================] - 7s 622ms/step - loss: 0.0178 - val_loss: 0.0204
# Epoch 99/100
# 11/11 [==============================] - 7s 619ms/step - loss: 0.0145 - val_loss: 0.0202
# Epoch 100/100
# 11/11 [==============================] - 7s 622ms/step - loss: 0.0136 - val_loss: 0.0202

# %% [markdown]
# ## 시맨틱 세그멘테이션 모델 시각화
# 이번에는 학습한 모델의 결과를 눈으로 확인해볼 차례이다. 테스트 셋은 이미지를 제공하지만 정답 데이터를 제공하지 않으니 눈으로 확인할 수 있도록 모델이 추론(inference)한 결과를 우리의 눈으로 볼 수 있는 세그멘테이션 이미지로 만들어주자!
#
# 이때 입력 이미지와 라벨을 한번에 볼 수 있도록 모델의 출력값을 입력 이미지 위에 겹쳐서 보이기, 즉 __오버레이(overray)__ 하자. PIL 패키지를 사용한다면 `Image.blend`를 활용할 수 있다.
#
# (참고) 이전 스텝에서 저장된 모델은 이후 아래와 같이 로드해서 활용할 수 있다.
#
# ```bash
# model = tf.keras.models.load_model(model_path)
# ```

# %%
def get_output(model, preproc, image_path, output_path):
    origin_img = imread(image_path)
    data = {"image":origin_img}
    processed = preproc(**data)
    output = model(np.expand_dims(processed["image"]/255,axis=0))
    output = (output[0].numpy()>0.5).astype(np.uint8).squeeze(-1)*255  #0.5라는 threshold를 변경하면 도로인식 결과범위가 달라집니다.
    output = Image.fromarray(output)
    background = Image.fromarray(origin_img).convert('RGBA')
    output = output.resize((origin_img.shape[1], origin_img.shape[0])).convert('RGBA')
    output = Image.blend(background, output, alpha=0.5)
    output.show()
    return output

# %% [markdown]
# 세그멘테이션이 성능을 정량적으로 측정하기 위한 방법으로 IoU(Intersection over Union)를 계산하게 된다. IoU를 계산하는 방법은 지난 시간에 소개한 바 있으므로 해당 내용을 활용하여 구현해보겠다.
#
# IoU를 계산하려면 모델이 도로 영역이라고 판단한 부분이 1로, 나머지 부분이 0으로 표시된 행렬, 그리고 라벨 데이터에서 도로 영역이 1, 나머지 부분이 0으로 표시된 행렬이 필요하다. 각각을 `prediction`, `target`이라고 불렀을 때 이를 계산하는 함수를 구현해 보겠다. 위에 구현했던 `get_output`을 좀더 확장해서 output, prediction, target을 함께 리턴하도록 구현해보자.

# %%
def calculate_iou_score(target, prediction):
    intersection = np.logical_and(target, prediction)
    union = np.logical_or(target, prediction)
    iou_score = float(np.sum(intersection)) / float(np.sum(union))
    print('IoU : %f' % iou_score )
    return iou_score

# %%
def get_output(model, preproc, image_path, output_path, label_path):
    origin_img = imread(image_path)
    data = {"image":origin_img}
    processed = preproc(**data)
    output = model(np.expand_dims(processed["image"]/255,axis=0))
    output = (output[0].numpy()>=0.5).astype(np.uint8).squeeze(-1)*255  #0.5라는 threshold를 변경하면 도로인식 결과범위가 달라집니다.
    prediction = output/255   # 도로로 판단한 영역
    
    output = Image.fromarray(output)
    background = Image.fromarray(origin_img).convert('RGBA')
    output = output.resize((origin_img.shape[1], origin_img.shape[0])).convert('RGBA')
    output = Image.blend(background, output, alpha=0.5)
    output.show()   # 도로로 판단한 영역을 시각화!
     
    if label_path:   
        label_img = imread(label_path)
        label_data = {"image":label_img}
        label_processed = preproc(**label_data)
        label_processed = label_processed["image"]
        target = (label_processed == 7).astype(np.uint8)*1   # 라벨에서 도로로 기재된 영역

        return output, prediction, target
    else:
        return output, prediction, _

# %% [markdown]
# #### U-Net

# %%
# 완성한 뒤에는 시각화한 결과를 눈으로 확인해봅시다!
i = 1    # i값을 바꾸면 테스트용 파일이 달라집니다. 
output, prediction, target = get_output(
     model, 
     test_preproc,
     image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_path + f'./result_{str(i).zfill(3)}.png',
     label_path=dir_path + f'/semantic/00{str(i).zfill(4)}_10.png'
 )

calculate_iou_score(target, prediction)
# Out:
# IoU : 0.836318
# 0.8363183735564622

# %%
augmentation = build_augmentation()
test_preproc = build_augmentation(is_train=False)
        
train_generator = KittiGenerator(
    dir_path, 
    augmentation=augmentation,
)

test_generator = KittiGenerator(
    dir_path, 
    augmentation=test_preproc,
    is_train=False
)

# %% [markdown]
# ### Step 2. U-Net++ 모델의 구현
# ---
# U-Net의 모델 구조와 소스코드를 면밀히 비교해 보다 보면, U-Net++를 어떻게 구현할 수 있을지에 대한 방안을 떠올릴 수 있을 것이다. 이 과정을 통해 U-Net 자체에 대한 이해도도 증진될 것이다.<br>
# 그 외 적절히 U-Net의 백본구조, 기타 파라미터 변경 등을 통해 추가적인 성능향상이 가능할수도 있다.
#
# 구현은 [여기](https://github.com/CarryHJR/Nested-UNet/blob/master/model.py)를 참조했다.

# %%
def conv_block(input,x):
    conv = Conv2D(input,3, padding='same',kernel_initializer='he_normal')(x)
    conv = BatchNormalization()(conv)
    conv = ReLU()(conv)
    conv = Conv2D(input,3, padding='same',kernel_initializer='he_normal')(conv)
    conv = BatchNormalization()(conv)
    conv = ReLU()(conv)
    return conv

def Up(input,x):
    convT = Conv2DTranspose(input,2,padding='same',strides=2)(x)
    convT = BatchNormalization()(convT)
    convT = ReLU()(convT)
    return convT

# %%
def UNet_Plus_build_model(input_shape=(224, 224, 3)):
    input = Input(input_shape)
    
    #Contracting Path
    conv0_0 = conv_block(64, input)
    pool0 = MaxPooling2D(pool_size=(2, 2))(conv0_0)
    conv1_0 = conv_block(128, pool0)
    cnct0_1 = concatenate([conv0_0,Up(64,conv1_0)])
    
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1_0)
    conv2_0 = conv_block(256, pool1)
    
    cnct1_1 = concatenate([conv1_0,Up(128,conv2_0)])
    cnct0_2 = concatenate([cnct0_1, cnct0_1, Up(128,cnct1_1)])
    
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2_0)
    conv3_0 = conv_block(512, pool2)
    
    cnct2_1 = concatenate([conv2_0, Up(256,conv3_0)])
    cnct1_2 = concatenate([cnct1_1, conv1_0, Up(256,cnct2_1)])
    cnct0_3 = concatenate([cnct0_1, conv0_0, cnct0_2, Up(256,cnct1_2)])
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3_0)
    conv4_0 = conv_block(1024, pool3)
    
    conv3_1 = conv_block(512,concatenate([conv3_0,Up(512, conv4_0)])) 
    conv2_2 = conv_block(256,concatenate([conv2_0, cnct2_1, Up(256, conv3_1)]))
    conv1_3 = conv_block(128,concatenate([conv1_0, cnct1_1, cnct1_2, Up(128, conv2_2)]))
    conv0_4 = conv_block(64,concatenate([conv0_0, cnct0_1, cnct0_2, cnct0_3, Up(64, conv1_3)]))
    
    x = Conv2D(2, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv0_4)
    out = Conv2D(1, 1, activation='sigmoid')(x)
    model = Model(inputs = input, outputs = out)
    return model

# %%
model = UNet_Plus_build_model()
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 224, 224, 64) 1792        input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 224, 224, 64) 256         conv2d_40[0][0]
# __________________________________________________________________________________________________
# re_lu_56 (ReLU)                 (None, 224, 224, 64) 0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 224, 224, 64) 36928       re_lu_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 224, 224, 64) 256         conv2d_41[0][0]
# __________________________________________________________________________________________________
# re_lu_57 (ReLU)                 (None, 224, 224, 64) 0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 112, 112, 64) 0           re_lu_57[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 112, 112, 128 73856       max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 112, 112, 128 512         conv2d_42[0][0]
# __________________________________________________________________________________________________
# re_lu_58 (ReLU)                 (None, 112, 112, 128 0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 112, 112, 128 147584      re_lu_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 112, 112, 128 512         conv2d_43[0][0]
# __________________________________________________________________________________________________
# re_lu_59 (ReLU)                 (None, 112, 112, 128 0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 56, 56, 128)  0           re_lu_59[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 56, 56, 256)  295168      max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 56, 56, 256)  1024        conv2d_44[0][0]
# __________________________________________________________________________________________________
# re_lu_61 (ReLU)                 (None, 56, 56, 256)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 56, 56, 256)  590080      re_lu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 56, 56, 256)  1024        conv2d_45[0][0]
# __________________________________________________________________________________________________
# re_lu_62 (ReLU)                 (None, 56, 56, 256)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D) (None, 28, 28, 256)  0           re_lu_62[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 28, 28, 512)  1180160     max_pooling2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 28, 28, 512)  2048        conv2d_46[0][0]
# __________________________________________________________________________________________________
# re_lu_65 (ReLU)                 (None, 28, 28, 512)  0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 28, 28, 512)  2359808     re_lu_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 28, 28, 512)  2048        conv2d_47[0][0]
# __________________________________________________________________________________________________
# re_lu_66 (ReLU)                 (None, 28, 28, 512)  0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 14, 14, 512)  0           re_lu_66[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 14, 14, 1024) 4719616     max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 14, 14, 1024) 4096        conv2d_48[0][0]
# __________________________________________________________________________________________________
# re_lu_70 (ReLU)                 (None, 14, 14, 1024) 0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 14, 14, 1024) 9438208     re_lu_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 14, 14, 1024) 4096        conv2d_49[0][0]
# __________________________________________________________________________________________________
# re_lu_71 (ReLU)                 (None, 14, 14, 1024) 0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_26 (Conv2DTran (None, 28, 28, 512)  2097664     re_lu_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 28, 28, 512)  2048        conv2d_transpose_26[0][0]
# __________________________________________________________________________________________________
# re_lu_72 (ReLU)                 (None, 28, 28, 512)  0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 28, 28, 1024) 0           re_lu_66[0][0]
#                                                                  re_lu_72[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 28, 28, 512)  4719104     concatenate_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 28, 28, 512)  2048        conv2d_50[0][0]
# __________________________________________________________________________________________________
# re_lu_73 (ReLU)                 (None, 28, 28, 512)  0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 28, 28, 512)  2359808     re_lu_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 28, 28, 512)  2048        conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_23 (Conv2DTran (None, 56, 56, 256)  524544      re_lu_66[0][0]
# __________________________________________________________________________________________________
# re_lu_74 (ReLU)                 (None, 28, 28, 512)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 56, 56, 256)  1024        conv2d_transpose_23[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_27 (Conv2DTran (None, 56, 56, 256)  524544      re_lu_74[0][0]
# __________________________________________________________________________________________________
# re_lu_67 (ReLU)                 (None, 56, 56, 256)  0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 56, 56, 256)  1024        conv2d_transpose_27[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 56, 56, 512)  0           re_lu_62[0][0]
#                                                                  re_lu_67[0][0]
# __________________________________________________________________________________________________
# re_lu_75 (ReLU)                 (None, 56, 56, 256)  0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 56, 56, 1024) 0           re_lu_62[0][0]
#                                                                  concatenate_23[0][0]
#                                                                  re_lu_75[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 56, 56, 256)  2359552     concatenate_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 56, 56, 256)  1024        conv2d_52[0][0]
# __________________________________________________________________________________________________
# re_lu_76 (ReLU)                 (None, 56, 56, 256)  0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 56, 56, 256)  590080      re_lu_76[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_21 (Conv2DTran (None, 112, 112, 128 131200      re_lu_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 56, 56, 256)  1024        conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 112, 112, 128 512         conv2d_transpose_21[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_24 (Conv2DTran (None, 112, 112, 256 524544      concatenate_23[0][0]
# __________________________________________________________________________________________________
# re_lu_77 (ReLU)                 (None, 56, 56, 256)  0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# re_lu_63 (ReLU)                 (None, 112, 112, 128 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 112, 112, 256 1024        conv2d_transpose_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_28 (Conv2DTran (None, 112, 112, 128 131200      re_lu_77[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 112, 112, 256 0           re_lu_59[0][0]
#                                                                  re_lu_63[0][0]
# __________________________________________________________________________________________________
# re_lu_68 (ReLU)                 (None, 112, 112, 256 0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 112, 112, 128 512         conv2d_transpose_28[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 112, 112, 640 0           concatenate_21[0][0]
#                                                                  re_lu_59[0][0]
#                                                                  re_lu_68[0][0]
# __________________________________________________________________________________________________
# re_lu_78 (ReLU)                 (None, 112, 112, 128 0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 112, 112, 115 0           re_lu_59[0][0]
#                                                                  concatenate_21[0][0]
#                                                                  concatenate_24[0][0]
#                                                                  re_lu_78[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 112, 112, 128 1327232     concatenate_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 112, 112, 128 512         conv2d_54[0][0]
# __________________________________________________________________________________________________
# re_lu_79 (ReLU)                 (None, 112, 112, 128 0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_20 (Conv2DTran (None, 224, 224, 64) 32832       re_lu_59[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 112, 112, 128 147584      re_lu_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 224, 224, 64) 256         conv2d_transpose_20[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_22 (Conv2DTran (None, 224, 224, 128 131200      concatenate_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 112, 112, 128 512         conv2d_55[0][0]
# __________________________________________________________________________________________________
# re_lu_60 (ReLU)                 (None, 224, 224, 64) 0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 224, 224, 128 512         conv2d_transpose_22[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_25 (Conv2DTran (None, 224, 224, 256 655616      concatenate_24[0][0]
# __________________________________________________________________________________________________
# re_lu_80 (ReLU)                 (None, 112, 112, 128 0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 224, 224, 128 0           re_lu_57[0][0]
#                                                                  re_lu_60[0][0]
# __________________________________________________________________________________________________
# re_lu_64 (ReLU)                 (None, 224, 224, 128 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 224, 224, 256 1024        conv2d_transpose_25[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_29 (Conv2DTran (None, 224, 224, 64) 32832       re_lu_80[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 224, 224, 384 0           concatenate_20[0][0]
#                                                                  concatenate_20[0][0]
#                                                                  re_lu_64[0][0]
# __________________________________________________________________________________________________
# re_lu_69 (ReLU)                 (None, 224, 224, 256 0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 224, 224, 64) 256         conv2d_transpose_29[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 224, 224, 832 0           concatenate_20[0][0]
#                                                                  re_lu_57[0][0]
#                                                                  concatenate_22[0][0]
#                                                                  re_lu_69[0][0]
# __________________________________________________________________________________________________
# re_lu_81 (ReLU)                 (None, 224, 224, 64) 0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 224, 224, 147 0           re_lu_57[0][0]
#                                                                  concatenate_20[0][0]
#                                                                  concatenate_22[0][0]
#                                                                  concatenate_25[0][0]
#                                                                  re_lu_81[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 224, 224, 64) 847936      concatenate_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 224, 224, 64) 256         conv2d_56[0][0]
# __________________________________________________________________________________________________
# re_lu_82 (ReLU)                 (None, 224, 224, 64) 0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 224, 224, 64) 36928       re_lu_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 224, 224, 64) 256         conv2d_57[0][0]
# __________________________________________________________________________________________________
# re_lu_83 (ReLU)                 (None, 224, 224, 64) 0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 224, 224, 2)  1154        re_lu_83[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 224, 224, 1)  3           conv2d_58[0][0]
# ==================================================================================================
# Total params: 36,050,501
# Trainable params: 36,034,629
# Non-trainable params: 15,872
# __________________________________________________________________________________________________

# %%
model.compile(optimizer = Adam(lr = 1e-4), loss = 'binary_crossentropy')
model.fit_generator(
     generator=train_generator,
     validation_data=test_generator,
     steps_per_epoch=len(train_generator),
     epochs=100,
 )

model_path = dir_path + '/seg_model_uppnet_unet.h5'
model.save(model_path)  #학습한 모델을 저장해 주세요.
# Out:
# Epoch 1/100
# 85/85 [==============================] - 28s 300ms/step - loss: 0.3524 - val_loss: 0.3048
# Epoch 2/100
# 85/85 [==============================] - 27s 316ms/step - loss: 0.1951 - val_loss: 0.2496
# Epoch 3/100
# 85/85 [==============================] - 30s 353ms/step - loss: 0.1514 - val_loss: 0.1344
# Epoch 4/100
# 85/85 [==============================] - 29s 341ms/step - loss: 0.1356 - val_loss: 0.1368
# Epoch 5/100
# 85/85 [==============================] - 28s 326ms/step - loss: 0.1193 - val_loss: 0.1508
# Epoch 6/100
# 85/85 [==============================] - 27s 316ms/step - loss: 0.1107 - val_loss: 0.1398
# Epoch 7/100
# 85/85 [==============================] - 26s 305ms/step - loss: 0.1015 - val_loss: 0.1048
# Epoch 8/100
# 85/85 [==============================] - 27s 316ms/step - loss: 0.1108 - val_loss: 0.0975
# Epoch 9/100
# 85/85 [==============================] - 27s 316ms/step - loss: 0.0915 - val_loss: 0.2704
# Epoch 10/100
# 85/85 [==============================] - 26s 303ms/step - loss: 0.0864 - val_loss: 0.1791
# Epoch 11/100
# 85/85 [==============================] - 31s 368ms/step - loss: 0.0946 - val_loss: 0.0950
# Epoch 12/100
# 85/85 [==============================] - 34s 403ms/step - loss: 0.0866 - val_loss: 0.0931
# Epoch 13/100
# 85/85 [==============================] - 30s 347ms/step - loss: 0.0827 - val_loss: 0.1488
# Epoch 14/100
# 85/85 [==============================] - 27s 314ms/step - loss: 0.0888 - val_loss: 0.0860
# Epoch 15/100
# 85/85 [==============================] - 26s 300ms/step - loss: 0.0864 - val_loss: 0.0865
# Epoch 16/100
# 85/85 [==============================] - 26s 306ms/step - loss: 0.0819 - val_loss: 0.0856
# Epoch 17/100
# 85/85 [==============================] - 27s 318ms/step - loss: 0.0709 - val_loss: 0.1124
# Epoch 18/100
# 85/85 [==============================] - 27s 321ms/step - loss: 0.0930 - val_loss: 0.0716
# Epoch 19/100
# 85/85 [==============================] - 26s 306ms/step - loss: 0.0652 - val_loss: 0.1653
# Epoch 20/100
# 85/85 [==============================] - 27s 314ms/step - loss: 0.0680 - val_loss: 0.0936
# Epoch 21/100
# 85/85 [==============================] - 26s 310ms/step - loss: 0.0779 - val_loss: 0.1870
# Epoch 22/100
# 85/85 [==============================] - 26s 310ms/step - loss: 0.0726 - val_loss: 0.0844
# Epoch 23/100
# 85/85 [==============================] - 27s 314ms/step - loss: 0.0623 - val_loss: 0.0736
# Epoch 24/100
# 85/85 [==============================] - 28s 327ms/step - loss: 0.0988 - val_loss: 0.1078
# Epoch 25/100
# 85/85 [==============================] - 28s 324ms/step - loss: 0.0669 - val_loss: 0.0892
# Epoch 26/100
# 85/85 [==============================] - 27s 318ms/step - loss: 0.0647 - val_loss: 0.0789
# Epoch 27/100
# 85/85 [==============================] - 25s 297ms/step - loss: 0.0557 - val_loss: 0.0846
# Epoch 28/100
# 85/85 [==============================] - 25s 296ms/step - loss: 0.0667 - val_loss: 0.0711
# Epoch 29/100
# 85/85 [==============================] - 26s 310ms/step - loss: 0.0768 - val_loss: 0.0882
# Epoch 30/100
# 85/85 [==============================] - 26s 310ms/step - loss: 0.0628 - val_loss: 0.0761
# Epoch 31/100
# 85/85 [==============================] - 27s 323ms/step - loss: 0.0524 - val_loss: 0.0782
# Epoch 32/100
# 85/85 [==============================] - 26s 307ms/step - loss: 0.0797 - val_loss: 0.0661
# Epoch 33/100
# 85/85 [==============================] - 26s 301ms/step - loss: 0.0687 - val_loss: 0.0746
# Epoch 34/100
# 85/85 [==============================] - 26s 309ms/step - loss: 0.0691 - val_loss: 0.0857
# Epoch 35/100
# 85/85 [==============================] - 30s 354ms/step - loss: 0.0509 - val_loss: 0.0907
# Epoch 36/100
# 85/85 [==============================] - 28s 333ms/step - loss: 0.0809 - val_loss: 0.0729
# Epoch 37/100
# 85/85 [==============================] - 26s 310ms/step - loss: 0.0693 - val_loss: 0.0930
# Epoch 38/100
# 85/85 [==============================] - 27s 317ms/step - loss: 0.0656 - val_loss: 0.0733
# Epoch 39/100
# 85/85 [==============================] - 28s 326ms/step - loss: 0.0763 - val_loss: 0.0842
# Epoch 40/100
# 85/85 [==============================] - 27s 317ms/step - loss: 0.0511 - val_loss: 0.0895
# Epoch 41/100
# 85/85 [==============================] - 26s 304ms/step - loss: 0.0531 - val_loss: 0.1379
# Epoch 42/100
# 85/85 [==============================] - 26s 309ms/step - loss: 0.0762 - val_loss: 0.1239
# Epoch 43/100
# 85/85 [==============================] - 28s 324ms/step - loss: 0.0644 - val_loss: 0.0773
# Epoch 44/100
# 85/85 [==============================] - 28s 325ms/step - loss: 0.0582 - val_loss: 0.0991
# Epoch 45/100
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0524 - val_loss: 0.0864
# Epoch 46/100
# 85/85 [==============================] - 30s 352ms/step - loss: 0.0547 - val_loss: 0.0857
# Epoch 47/100
# 85/85 [==============================] - 28s 327ms/step - loss: 0.0748 - val_loss: 0.0881
# Epoch 48/100
# 85/85 [==============================] - 28s 329ms/step - loss: 0.0515 - val_loss: 0.0698
# Epoch 49/100
# 85/85 [==============================] - 28s 325ms/step - loss: 0.0508 - val_loss: 0.0888
# Epoch 50/100
# 85/85 [==============================] - 27s 312ms/step - loss: 0.0520 - val_loss: 0.0928
# Epoch 51/100
# 85/85 [==============================] - 25s 291ms/step - loss: 0.0579 - val_loss: 0.0690
# Epoch 52/100
# 85/85 [==============================] - 28s 332ms/step - loss: 0.0622 - val_loss: 0.0749
# Epoch 53/100
# 85/85 [==============================] - 30s 351ms/step - loss: 0.0564 - val_loss: 0.0745
# Epoch 54/100
# 85/85 [==============================] - 30s 352ms/step - loss: 0.0567 - val_loss: 0.0894
# Epoch 55/100
# 85/85 [==============================] - 30s 352ms/step - loss: 0.0579 - val_loss: 0.0728
# Epoch 56/100
# 85/85 [==============================] - 30s 350ms/step - loss: 0.0510 - val_loss: 0.0632
# Epoch 57/100
# 85/85 [==============================] - 29s 336ms/step - loss: 0.0536 - val_loss: 0.1737
# Epoch 58/100
# 85/85 [==============================] - 30s 349ms/step - loss: 0.0517 - val_loss: 0.0705
# Epoch 59/100
# 85/85 [==============================] - 30s 354ms/step - loss: 0.0518 - val_loss: 0.0788
# Epoch 60/100
# 85/85 [==============================] - 30s 355ms/step - loss: 0.0436 - val_loss: 0.0873
# Epoch 61/100
# 85/85 [==============================] - 29s 336ms/step - loss: 0.0536 - val_loss: 0.0719
# Epoch 62/100
# 85/85 [==============================] - 29s 344ms/step - loss: 0.0497 - val_loss: 0.0880
# Epoch 63/100
# 85/85 [==============================] - 29s 344ms/step - loss: 0.0400 - val_loss: 0.0843
# Epoch 64/100
# 85/85 [==============================] - 23s 271ms/step - loss: 0.0590 - val_loss: 0.1059
# Epoch 65/100
# 85/85 [==============================] - 23s 274ms/step - loss: 0.0586 - val_loss: 0.0905
# Epoch 66/100
# 85/85 [==============================] - 23s 273ms/step - loss: 0.0442 - val_loss: 0.0802
# Epoch 67/100
# 85/85 [==============================] - 28s 330ms/step - loss: 0.0538 - val_loss: 0.2719
# Epoch 68/100
# 85/85 [==============================] - 29s 339ms/step - loss: 0.0579 - val_loss: 0.0854
# Epoch 69/100
# 85/85 [==============================] - 27s 318ms/step - loss: 0.0393 - val_loss: 0.0867
# Epoch 70/100
# 85/85 [==============================] - 28s 334ms/step - loss: 0.0415 - val_loss: 0.0679
# Epoch 71/100
# 85/85 [==============================] - 24s 282ms/step - loss: 0.0458 - val_loss: 0.1164
# Epoch 72/100
# 85/85 [==============================] - 36s 421ms/step - loss: 0.0472 - val_loss: 0.1203
# Epoch 73/100
# 85/85 [==============================] - 31s 364ms/step - loss: 0.0526 - val_loss: 0.1163
# Epoch 74/100
# 85/85 [==============================] - 24s 280ms/step - loss: 0.0434 - val_loss: 0.2379
# Epoch 75/100
# 85/85 [==============================] - 25s 295ms/step - loss: 0.0419 - val_loss: 0.0779
# Epoch 76/100
# 85/85 [==============================] - 25s 296ms/step - loss: 0.0895 - val_loss: 0.0864
# Epoch 77/100
# 85/85 [==============================] - 25s 296ms/step - loss: 0.0712 - val_loss: 0.0679
# Epoch 78/100
# 85/85 [==============================] - 25s 296ms/step - loss: 0.0456 - val_loss: 0.0766
# Epoch 79/100
# 85/85 [==============================] - 25s 297ms/step - loss: 0.0417 - val_loss: 0.0910
# Epoch 80/100
# 85/85 [==============================] - 25s 297ms/step - loss: 0.0502 - val_loss: 0.0979
# Epoch 81/100
# 85/85 [==============================] - 25s 289ms/step - loss: 0.0581 - val_loss: 0.0791
# Epoch 82/100
# 85/85 [==============================] - 25s 293ms/step - loss: 0.0589 - val_loss: 0.0755
# Epoch 83/100
# 85/85 [==============================] - 25s 296ms/step - loss: 0.0428 - val_loss: 0.0712
# Epoch 84/100
# 85/85 [==============================] - 25s 297ms/step - loss: 0.0430 - val_loss: 0.0866
# Epoch 85/100
# 85/85 [==============================] - 25s 300ms/step - loss: 0.0408 - val_loss: 0.0868
# Epoch 86/100
# 85/85 [==============================] - 26s 303ms/step - loss: 0.0579 - val_loss: 0.0843
# Epoch 87/100
# 85/85 [==============================] - 26s 302ms/step - loss: 0.0460 - val_loss: 0.0615
# Epoch 88/100
# 85/85 [==============================] - 25s 294ms/step - loss: 0.0508 - val_loss: 0.0658
# Epoch 89/100
# 85/85 [==============================] - 23s 267ms/step - loss: 0.0442 - val_loss: 0.0739
# Epoch 90/100
# 85/85 [==============================] - 23s 273ms/step - loss: 0.0397 - val_loss: 0.0711
# Epoch 91/100
# 85/85 [==============================] - 23s 267ms/step - loss: 0.0388 - val_loss: 0.0972
# Epoch 92/100
# 85/85 [==============================] - 23s 267ms/step - loss: 0.0494 - val_loss: 0.0763
# Epoch 93/100
# 85/85 [==============================] - 23s 267ms/step - loss: 0.0410 - val_loss: 0.0687
# Epoch 94/100
# 85/85 [==============================] - 23s 267ms/step - loss: 0.0402 - val_loss: 0.0554
# Epoch 95/100
# 85/85 [==============================] - 23s 267ms/step - loss: 0.0456 - val_loss: 0.0664
# Epoch 96/100
# 85/85 [==============================] - 23s 267ms/step - loss: 0.0479 - val_loss: 0.0751
# Epoch 97/100
# 85/85 [==============================] - 23s 267ms/step - loss: 0.0332 - val_loss: 0.0786
# Epoch 98/100
# 85/85 [==============================] - 23s 269ms/step - loss: 0.0354 - val_loss: 0.0992
# Epoch 99/100
# 85/85 [==============================] - 23s 274ms/step - loss: 0.0439 - val_loss: 0.0753
# Epoch 100/100
# 85/85 [==============================] - 23s 268ms/step - loss: 0.0392 - val_loss: 0.1205

# %% [markdown]
# #### U-Net++

# %%
# 완성한 뒤에는 시각화한 결과를 눈으로 확인해봅시다!
i = 1    # i값을 바꾸면 테스트용 파일이 달라집니다. 
output, prediction, target = get_output(
     model, 
     test_preproc,
     image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_path + f'./result_{str(i).zfill(3)}.png',
     label_path=dir_path + f'/semantic/00{str(i).zfill(4)}_10.png'
 )

calculate_iou_score(target, prediction)
# Out:
# IoU : 0.900000
# 0.9

# %% [markdown]
# ### Step 3. U-Net 과 U-Net++ 모델이 수행한 세그멘테이션 결과 분석
# ---
# 두 모델의 정량적, 정성적 성능을 비교해보자. 시각화, IoU 계산 등을 체계적으로 시도해 보면 차이를 발견할 수 있을 것이다.

# %% [markdown]
# ####  U-Net
#
# <img src="./image/result1.png" />
#
# IoU : 0.836318

# %% [markdown]
# ####  U-Net++
#
# <img src="./image/result2.png" />
#
# IoU : 0.900000

# %% [markdown]
# ### 회고
# ---
# * SIA 프로젝트 할때 도움이 될만한 노드였다.
# * 채은님의 도움으로 U-Net++을 이해했고, 쌓아보니 재미있었다.

# %% [markdown]
# ### 루브릭
# ---
# * U-Net을 통한 세그멘테이션 작업이 정상적으로 진행되었는가?<br>
# (_KITTI 데이터셋 구성, U-Net 모델 훈련, 결과물 시각화의 한사이클이 정상수행되어 세그멘테이션 결과이미지를 제출하였다._)
#
#     * __세그멘테이션 결과이미지를 제출했다.__
#
# * U-Net++ 모델이 성공적으로 구현되었는가?<br>
# ( _U-Net++ 모델을 스스로 구현하여 학습 진행 후 세그멘테이션 결과까지 정상진행되었다._)
#
#     * __U-Net++ 모델을 구현하고 결과 확인까지 진행했다.__
#
# * U-Net과 U-Net++ 두 모델의 성능이 정량적/정성적으로 잘 비교되었는가?<br>
# (_U-Net++ 의 세그멘테이션 결과 사진와 IoU 계산치를 U-Net과 비교하여 우월함을 확인하였다._)
#
#     * __U-Net++ 모델이 더 성능향상이 되었다.__
